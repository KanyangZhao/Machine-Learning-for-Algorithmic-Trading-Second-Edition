# %% [markdown]
# # Working with Order Book Data: NASDAQ ITCH

# %% [markdown]
# The primary source of market data is the order book, which is continuously updated in real-time throughout the day to reflect all trading activity. Exchanges typically offer this data as a real-time service and may provide some historical data for free.
#
# The trading activity is reflected in numerous messages about trade orders sent by market participants. These messages typically conform to the electronic Financial Information eXchange (FIX) communications protocol for real-time exchange of securities transactions and market data or a native exchange protocol.

# %% [markdown]
# ## Background

# %% [markdown]
# ### The FIX Protocol

# %% [markdown]
# Just like SWIFT is the message protocol for back-office (example, for trade-settlement) messaging, the [FIX protocol](https://www.fixtrading.org/standards/) is the de facto messaging standard for communication before and during, trade execution between exchanges, banks, brokers, clearing firms, and other market participants. Fidelity Investments and Salomon Brothers introduced FIX in 1992 to facilitate electronic communication between broker-dealers and institutional clients who by then exchanged information over the phone.
#
# It became popular in global equity markets before expanding into foreign exchange, fixed income and derivatives markets, and further into post-trade to support straight-through processing. Exchanges provide access to FIX messages as a real-time data feed that is parsed by algorithmic traders to track market activity and, for example, identify the footprint of market participants and anticipate their next move.

# %% [markdown]
# ### Nasdaq TotalView-ITCH Order Book data

# %% [markdown]
# While FIX has a dominant large market share, exchanges also offer native protocols. The Nasdaq offers a [TotalView ITCH direct data-feed protocol](http://www.nasdaqtrader.com/content/technicalsupport/specifications/dataproducts/NQTVITCHspecification.pdf) that allows subscribers to track
# individual orders for equity instruments from placement to execution or cancellation.
#
# As a result, it allows for the reconstruction of the order book that keeps track of the list of active-limit buy and sell orders for a specific security or financial instrument. The order book reveals the market depth throughout the day by listing the number of shares being bid or offered at each price point. It may also identify the market participant responsible for specific buy and sell orders unless it is placed anonymously. Market depth is a key indicator of liquidity and the potential price impact of sizable market orders.

# %% [markdown]
# The ITCH v5.0 specification declares over 20 message types related to system events, stock characteristics, the placement and modification of limit orders, and trade execution. It also contains information about the net order imbalance before the open and closing cross.

# %% [markdown]
# ## Imports

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline
import gzip
import shutil
from struct import unpack
from collections import namedtuple, Counter, defaultdict
from pathlib import Path
from urllib.request import urlretrieve
from urllib.parse import urljoin
from datetime import timedelta
from time import time

import pandas as pd

import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import seaborn as sns

# %%
sns.set_style('whitegrid')

# %%
def format_time(t):
    """Return a formatted time string 'HH:MM:SS
    based on a numeric time() value"""
    m, s = divmod(t, 60)
    h, m = divmod(m, 60)
    return f'{h:0>2.0f}:{m:0>2.0f}:{s:0>5.2f}'

# %% [markdown]
# ## Get NASDAQ ITCH Data from FTP Server

# %% [markdown]
# The Nasdaq offers [samples](https://emi.nasdaq.com/ITCH/Nasdaq%20ITCH/) of daily binary files for several months.
#
# We are now going to illustrates how to parse a sample file of ITCH messages and reconstruct both the executed trades and the order book for any given tick.

# %% [markdown]
# The data is fairly large and running the entire example can take a lot of time and require substantial memory (16GB+). Also, the sample file used in this example may no longer be available because NASDAQ occasionaly updates the sample files.

# %% [markdown]
# The following table shows the frequency of the most common message types for the sample file date March 29, 2018:

# %% [markdown]
# | Name                    | Offset  | Length  | Value      | Notes                                                                                |
# |-------------------------|---------|---------|------------|--------------------------------------------------------------------------------------|
# | Message Type            | 0       | 1       | S          | System Event Message                                                                 |
# | Stock Locate            | 1       | 2       | Integer    | Always 0                                                                             |
# | Tracking Number         | 3       | 2       | Integer    | Nasdaq internal tracking number                                                      |
# | Timestamp               | 5       | 6       | Integer    | Nanoseconds since midnight                                                           |
# | Order Reference Number  | 11      | 8       | Integer    | The unique reference number assigned to the new order at the time of receipt.        |
# | Buy/Sell Indicator      | 19      | 1       | Alpha      | The type of order being added. B = Buy Order. S = Sell Order.                        |
# | Shares                  | 20      | 4       | Integer    | The total number of shares associated with the order being added to the book.        |
# | Stock                   | 24      | 8       | Alpha      | Stock symbol, right padded with spaces                                               |
# | Price                   | 32      | 4       | Price (4)  | The display price of the new order. Refer to Data Types for field processing notes.  |
# | Attribution             | 36      | 4       | Alpha      | Nasdaq Market participant identifier associated with the entered order               |

# %% [markdown]
# ### Set Data paths

# %% [markdown]
# We will store the download in a `data` subdirectory and convert the result to `hdf` format (discussed in the last section of chapter 2).

# %%
data_path = Path('data') # set to e.g. external harddrive
itch_store = str(data_path / 'itch.h5')
order_book_store = data_path / 'order_book.h5'

# %% [markdown]
# You can find several sample files on the [NASDAQ server](https://emi.nasdaq.com/ITCH/Nasdaq%20ITCH/).
#
# The HTTPS address, filename and corresponding date used in this example:

# %%
HTTPS_URL = 'https://emi.nasdaq.com/ITCH/Nasdaq%20ITCH/'
SOURCE_FILE = '10302019.NASDAQ_ITCH50.gz'

# %% [markdown]
# #### URL updates
#
# NASDAQ updates the files occasionally so that the SOURCE_FILE changes. If the above gives an error, navigate to the HTTPS_URL using your browser, and check for new files. As of September 2021, the listed files include:
#
# - 01302020.NASDAQ_ITCH50.gz
# - 12302019.NASDAQ_ITCH50.gz
# - 10302019.NASDAQ_ITCH50.gz
# - 08302019.NASDAQ_ITCH50.gz
# - 07302019.NASDAQ_ITCH50.gz
# - 03272019.NASDAQ_ITCH50.gz
# - 01302019.NASDAQ_ITCH50.gz
# - 12282018.NASDAQ_ITCH50.gz

# %% [markdown]
# ### Download & unzip

# %%
def may_be_download(url):
    """Download & unzip ITCH data if not yet available"""
    if not data_path.exists():
        print('Creating directory')
        data_path.mkdir()
    else: 
        print('Directory exists')

    filename = data_path / url.split('/')[-1]        
    if not filename.exists():
        print('Downloading...', url)
        urlretrieve(url, filename)
    else: 
        print('File exists')        

    unzipped = data_path / (filename.stem + '.bin')
    if not unzipped.exists():
        print('Unzipping to', unzipped)
        with gzip.open(str(filename), 'rb') as f_in:
            with open(unzipped, 'wb') as f_out:
                shutil.copyfileobj(f_in, f_out)
    else: 
        print('File already unpacked')
    return unzipped

# %% [markdown]
# This will download 5.1GB data that unzips to 12.9GB (this may vary depending on the file, see 'url updates' below).

# %%
file_name = may_be_download(urljoin(HTTPS_URL, SOURCE_FILE))
date = file_name.name.split('.')[0]
# Out:
# Directory exists
# File exists
# File already unpacked

# %% [markdown]
# ## ITCH Format Settings

# %% [markdown]
# ### The `struct` module for binary data

# %% [markdown]
# The ITCH tick data comes in binary format. Python provides the `struct` module (see [docs](https://docs.python.org/3/library/struct.html)) to parse binary data using format strings that identify the message elements by indicating length and type of the various components of the byte string as laid out in the specification.

# %% [markdown]
# From the docs:
#
# > This module performs conversions between Python values and C structs represented as Python bytes objects. This can be used in handling binary data stored in files or from network connections, among other sources. It uses Format Strings as compact descriptions of the layout of the C structs and the intended conversion to/from Python values.

# %% [markdown]
# Let's walk through the critical steps to parse the trading messages and reconstruct the order book:

# %% [markdown]
# ### Defining format strings

# %% [markdown]
# The parser uses format strings according to the following formats dictionaries:

# %%
event_codes = {'O': 'Start of Messages',
               'S': 'Start of System Hours',
               'Q': 'Start of Market Hours',
               'M': 'End of Market Hours',
               'E': 'End of System Hours',
               'C': 'End of Messages'}

# %%
encoding = {'primary_market_maker': {'Y': 1, 'N': 0},
            'printable'           : {'Y': 1, 'N': 0},
            'buy_sell_indicator'  : {'B': 1, 'S': -1},
            'cross_type'          : {'O': 0, 'C': 1, 'H': 2},
            'imbalance_direction' : {'B': 0, 'S': 1, 'N': 0, 'O': -1}}

# %%
formats = {
    ('integer', 2): 'H',  # int of length 2 => format string 'H'
    ('integer', 4): 'I',
    ('integer', 6): '6s',  # int of length 6 => parse as string, convert later
    ('integer', 8): 'Q',
    ('alpha',   1): 's',
    ('alpha',   2): '2s',
    ('alpha',   4): '4s',
    ('alpha',   8): '8s',
    ('price_4', 4): 'I',
    ('price_8', 8): 'Q',
}

# %% [markdown]
# ### Create message specs for binary data parser

# %% [markdown]
# The ITCH parser relies on message specifications that we create in the following steps.

# %% [markdown]
# #### Load Message Types

# %% [markdown]
# The file `message_types.xlxs` contains the message type specs as laid out in the [documentation](https://www.nasdaqtrader.com/content/technicalsupport/specifications/dataproducts/NQTVITCHSpecification.pdf)

# %%
message_data = (pd.read_excel('message_types.xlsx',
                              sheet_name='messages')
                .sort_values('id')
                .drop('id', axis=1))

# %%
message_data.head()
# Out:
#               Name   Offset   Length     Value   \
# 0     Message Type         0        1         S
# 1     Stock Locate         1        2  Integer
# 2  Tracking Number         3        2  Integer
# 3        Timestamp         5        6  Integer
# 4       Event Code        11        1    Alpha
#
#                              Notes
# 0             System Event Message
# 1                         Always 0
# 2  Nasdaq internal tracking number
# 3       Nanoseconds since midnight
# 4     See System Event Codes below

# %% [markdown]
# #### Basic Cleaning

# %% [markdown]
# The function `clean_message_types()` just runs a few basic string cleaning steps.

# %%
def clean_message_types(df):
    df.columns = [c.lower().strip() for c in df.columns]
    df.value = df.value.str.strip()
    df.name = (df.name
               .str.strip() # remove whitespace
               .str.lower()
               .str.replace(' ', '_')
               .str.replace('-', '_')
               .str.replace('/', '_'))
    df.notes = df.notes.str.strip()
    df['message_type'] = df.loc[df.name == 'message_type', 'value']
    return df

# %%
message_types = clean_message_types(message_data)

# %%
message_types
# Out:
#                           name  offset  length      value  \
# 0                 message_type       0       1          S
# 1                 stock_locate       1       2    Integer
# 2              tracking_number       3       2    Integer
# 3                    timestamp       5       6    Integer
# 4                   event_code      11       1      Alpha
# ..                         ...     ...     ...        ...
# 168                  far_price      36       4  Price (4)
# 169                 near_price      40       4  Price (4)
# 170    current_reference_price      44       4  Price (4)
# 171                 cross_type      48       1      Alpha
# 172  price_variation_indicator      49       1      Alpha
#
#                                                  notes message_type
# 0                                 System Event Message            S
# 1                                             Always 0          NaN
# 2                      Nasdaq internal tracking number          NaN
# 3                           Nanoseconds since midnight          NaN
# 4                         See System Event Codes below          NaN
# ..                                                 ...          ...
# 168  A hypothetical auction-clearing price for cros...          NaN
# 169  A hypothetical auction-clearing price for cros...          NaN
# 170  The price at which the NOII shares are being c...          NaN
# 171  The type of Nasdaq cross for which the NOII me...          NaN
# 172  This field indicates the absolute value of the...          NaN
#
# [173 rows x 6 columns]

# %% [markdown]
# #### Get Message Labels

# %% [markdown]
# We extract message type codes and names so we can later make the results more readable.

# %%
message_labels = (message_types.loc[:, ['message_type', 'notes']]
                  .dropna()
                  .rename(columns={'notes': 'name'}))
message_labels.name = (message_labels.name
                       .str.lower()
                       .str.replace('message', '')
                       .str.replace('.', '')
                       .str.strip().str.replace(' ', '_'))
# message_labels.to_csv('message_labels.csv', index=False)
message_labels.head()
# Out:
#    message_type                                               name
# 0             S                                       system_event
# 5             R                                    stock_directory
# 23            H                               stock_trading_action
# 31            Y  reg_sho_short_sale_price_test_restricted_indic...
# 37            L                        market_participant_position

# %% [markdown]
# ### Finalize specification details

# %% [markdown]
# Each message consists of several fields that are defined by offset, length and type of value. The `struct` module will use this format information to parse the binary source data.

# %%
message_types.message_type = message_types.message_type.ffill()
message_types = message_types[message_types.name != 'message_type']
message_types.value = (message_types.value
                       .str.lower()
                       .str.replace(' ', '_')
                       .str.replace('(', '')
                       .str.replace(')', ''))
message_types.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 152 entries, 1 to 172
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          152 non-null    object
#  1   offset        152 non-null    int64
#  2   length        152 non-null    int64
#  3   value         152 non-null    object
#  4   notes         152 non-null    object
#  5   message_type  152 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 8.3+ KB

# %%
message_types.head()
# Out:
#               name  offset  length    value  \
# 1     stock_locate       1       2  integer
# 2  tracking_number       3       2  integer
# 3        timestamp       5       6  integer
# 4       event_code      11       1    alpha
# 6     stock_locate       1       2  integer
#
#                                                notes message_type
# 1                                           Always 0            S
# 2                    Nasdaq internal tracking number            S
# 3                         Nanoseconds since midnight            S
# 4                       See System Event Codes below            S
# 6  Locate Code uniquely assigned to the security ...            R

# %% [markdown]
# Optionally, persist/reload from file:

# %%
message_types.to_csv('message_types.csv', index=False)

# %%
message_types = pd.read_csv('message_types.csv')

# %% [markdown]
# The parser translates the message specs into format strings and `namedtuples` that capture the message content. First, we create `(type, length)` formatting tuples from ITCH specs:

# %%
message_types.loc[:, 'formats'] = (message_types[['value', 'length']]
                            .apply(tuple, axis=1).map(formats))
#先把dataframe中的value和length转换为tuple，再通过map获取format中的映射，即取字典中key对应的value

# %%
message_types
# Out:
#                           name  offset  length    value  \
# 0                 stock_locate       1       2  integer
# 1              tracking_number       3       2  integer
# 2                    timestamp       5       6  integer
# 3                   event_code      11       1    alpha
# 4                 stock_locate       1       2  integer
# ..                         ...     ...     ...      ...
# 147                  far_price      36       4  price_4
# 148                 near_price      40       4  price_4
# 149    current_reference_price      44       4  price_4
# 150                 cross_type      48       1    alpha
# 151  price_variation_indicator      49       1    alpha
#
#                                                  notes message_type formats
# 0                                             Always 0            S       H
# 1                      Nasdaq internal tracking number            S       H
# 2                           Nanoseconds since midnight            S      6s
# 3                         See System Event Codes below            S       s
# 4    Locate Code uniquely assigned to the security ...            R       H
# ..                                                 ...          ...     ...
# 147  A hypothetical auction-clearing price for cros...            I       I
# 148  A hypothetical auction-clearing price for cros...            I       I
# 149  The price at which the NOII shares are being c...            I       I
# 150  The type of Nasdaq cross for which the NOII me...            I       s
# 151  This field indicates the absolute value of the...            I       s
#
# [152 rows x 7 columns]

# %% [markdown]
# Then, we extract formatting details for alphanumerical fields

# %%
alpha_fields = message_types[message_types.value == 'alpha'].set_index('name')
alpha_msgs = alpha_fields.groupby('message_type') #按照messagetype进行分组
alpha_formats = {k: v.to_dict() for k, v in alpha_msgs.formats} #key为message_type，value为name和format组成的字典
alpha_length = {k: v.add(5).to_dict() for k, v in alpha_msgs.length}
#k是group的对象，v是group后的index和value，因此需要to_dict
#.add(5)是对所有的值+5

# %%
alpha_formats
# Out:
# {'A': {'buy_sell_indicator': 's', 'stock': '8s'},
#  'C': {'printable': 's'},
#  'F': {'buy_sell_indicator': 's', 'stock': '8s', 'attribution': '4s'},
#  'H': {'stock': '8s', 'trading_state': 's', 'reserved': 's', 'reason': '4s'},
#  'I': {'imbalance_direction': 's',
#   'stock': '8s',
#   'cross_type': 's',
#   'price_variation_indicator': 's'},
#  'J': {'stock': '8s'},
#  'K': {'stock': '8s', 'ipo_quotation_release_qualifier': 's'},
#  'L': {'mpid': '4s',
#   'stock': '8s',
#   'primary_market_maker': 's',
#   'market_maker_mode': 's',
#   'market_participant_state': 's'},
#  'P': {'buy_sell_indicator': 's', 'stock': '8s'},
#  'Q': {'stock': '8s', 'cross_type': 's'},
#  'R': {'stock': '8s',
#   'market_category': 's',
#   'financial_status_indicator': 's',
#   'round_lots_only': 's',
#   'issue_classification': 's',
#   'issue_sub_type': '2s',
#   'authenticity': 's',
#   'short_sale_threshold_indicator': 's',
#   'ipo_flag': 's',
#   'luld_reference_price_tier': 's',
#   'etp_flag': 's',
#   'inverse_indicator': 's'},
#  'S': {'event_code': 's'},
#  'W': {'breached_level': 's'},
#  'Y': {'stock': '8s', 'reg_sho_action': 's'},
#  'h': {'stock': '8s', 'market_code': 's', 'operational_halt_action': 's'}}

# %% [markdown]
# We generate message classes as named tuples and format strings

# %%
message_fields, fstring = {}, {}
for t, message in message_types.groupby('message_type'):
    message_fields[t] = namedtuple(typename=t, field_names=message.name.tolist()) 
    # namedtuple返回一个具名元组子类typename,其中参数的意义如下
    # typename:元组名称，此处为t，即分组后message_types的index
    # field_names:元组中元素的名称，此处为分组后message_types的name
    # 本质是生成一个namedtuple格式
    fstring[t] = '>' + ''.join(message.formats.tolist())
    # 将分组后message_types的formats生成list后合并为string

# %%
fstring
# Out:
# {'A': '>HH6sQsI8sI',
#  'B': '>HH6sQ',
#  'C': '>HH6sQIQsI',
#  'D': '>HH6sQ',
#  'E': '>HH6sQIQ',
#  'F': '>HH6sQsI8sI4s',
#  'H': '>HH6s8sss4s',
#  'I': '>HH6sQQs8sIIIss',
#  'J': '>HH6s8sIIII',
#  'K': '>HH6s8sIsI',
#  'L': '>HH6s4s8ssss',
#  'P': '>HH6sQsI8sIQ',
#  'Q': '>HH6sQ8sIQs',
#  'R': '>HH6s8sssIss2ssssssIs',
#  'S': '>HH6ss',
#  'U': '>HH6sQQII',
#  'V': '>HH6sQQQ',
#  'W': '>HH6ss',
#  'X': '>HH6sQI',
#  'Y': '>HH6s8ss',
#  'h': '>HH6s8sss'}

# %%
alpha_fields.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45 entries, event_code to price_variation_indicator
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   offset        45 non-null     int64
#  1   length        45 non-null     int64
#  2   value         45 non-null     object
#  3   notes         45 non-null     object
#  4   message_type  45 non-null     object
#  5   formats       45 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 2.5+ KB

# %%
alpha_fields.head()
# Out:
#                             offset  length  value  \
# name
# event_code                      11       1  alpha
# stock                           11       8  alpha
# market_category                 19       1  alpha
# financial_status_indicator      20       1  alpha
# round_lots_only                 25       1  alpha
#
#                                                                         notes  \
# name
# event_code                                       See System Event Codes below
# stock                       Denotes the security symbol for the issue in t...
# market_category             Indicates Listing market or listing market tie...
# financial_status_indicator  For Nasdaq listed issues, this field indicates...
# round_lots_only             Indicates if Nasdaq system limits order entry ...
#
#                            message_type formats
# name
# event_code                            S       s
# stock                                 R      8s
# market_category                       R       s
# financial_status_indicator            R       s
# round_lots_only                       R       s

# %%
alpha_formats
# Out:
# {'A': {'buy_sell_indicator': 's', 'stock': '8s'},
#  'C': {'printable': 's'},
#  'F': {'buy_sell_indicator': 's', 'stock': '8s', 'attribution': '4s'},
#  'H': {'stock': '8s', 'trading_state': 's', 'reserved': 's', 'reason': '4s'},
#  'I': {'imbalance_direction': 's',
#   'stock': '8s',
#   'cross_type': 's',
#   'price_variation_indicator': 's'},
#  'J': {'stock': '8s'},
#  'K': {'stock': '8s', 'ipo_quotation_release_qualifier': 's'},
#  'L': {'mpid': '4s',
#   'stock': '8s',
#   'primary_market_maker': 's',
#   'market_maker_mode': 's',
#   'market_participant_state': 's'},
#  'P': {'buy_sell_indicator': 's', 'stock': '8s'},
#  'Q': {'stock': '8s', 'cross_type': 's'},
#  'R': {'stock': '8s',
#   'market_category': 's',
#   'financial_status_indicator': 's',
#   'round_lots_only': 's',
#   'issue_classification': 's',
#   'issue_sub_type': '2s',
#   'authenticity': 's',
#   'short_sale_threshold_indicator': 's',
#   'ipo_flag': 's',
#   'luld_reference_price_tier': 's',
#   'etp_flag': 's',
#   'inverse_indicator': 's'},
#  'S': {'event_code': 's'},
#  'W': {'breached_level': 's'},
#  'Y': {'stock': '8s', 'reg_sho_action': 's'},
#  'h': {'stock': '8s', 'market_code': 's', 'operational_halt_action': 's'}}

# %% [markdown]
# Fields of `alpha` type (alphanumeric) require post-processing as defined in the `format_alpha` function:

# %%
def format_alpha(mtype, data):
    """Process byte strings of type alpha"""

    for col in alpha_formats.get(mtype).keys():
        if mtype != 'R' and col == 'stock': #如果mtype不是'R'并且找到了col为'stock'
            data = data.drop(col, axis=1) #data需要drop掉'stock'这一列
            continue
        data.loc[:, col] = data.loc[:, col].str.decode('utf-8').str.strip()
        #将列中的每个元素按照UTF-8编码解码为字符串。这通常用于处理二进制数据，将其转换为文本形式。移除字符串两端的空白字符（例如，空格、制表符等）
        if encoding.get(col):
            data.loc[:, col] = data.loc[:, col].map(encoding.get(col))
            #使用map方法将col列中的每个元素根据encoding字典进行映射。encoding.get(col)获取字典中键为col的对应值，然后map将列中的每个元素替换为对应的值。
    return data

# %%
format_alpha('Q', pd.DataFrame(messages['Q']))
# Out:
#        stock_locate  tracking_number                    timestamp  shares  \
# 0              1880                3     b'\x1a1\x85\xcb\x1a\x0b'     317
# 1              5400                1  b'\x1f\x1a\xce\xe3\x81\xf1'       0
# 2              4268                1     b'\x1f\x1a\xce\xeb9\xd7'       0
# 3              1764                1  b'\x1f\x1a\xce\xef\x98\xe0'       0
# 4              2225                1     b'\x1f\x1a\xce\xfa?\x1f'       1
# ...             ...              ...                          ...     ...
# 17769           973                1  b'\x1f\x1b\x07\xa6\xd3\x0f'       0
# 17770          1024                1     b'\x1f\x1b\x07\xa86\x10'    3456
# 17771          6497                1     b'\x1f\x1b\x07\xa9I\xea'       0
# 17772          4356                1     b'\x1f\x1b\x07\xa9\xecg'       0
# 17773          8360                1     b'\x1f\x1b\x07\xab \x9f'       0
#
#        cross_price  match_number cross_type
# 0            94800         26943          2
# 1                0         58610          0
# 2                0         58616          0
# 3                0         58620          0
# 4           256400         58628          0
# ...            ...           ...        ...
# 17769            0        164210          0
# 17770       437100        164211          0
# 17771            0        164213          0
# 17772            0        164216          0
# 17773            0        164219          0
#
# [17774 rows x 7 columns]

# %%
df = pd.DataFrame(messages['Q'])
df['cross_type'].str.decode('utf-8')
# Out:
# 0        H
# 1        O
# 2        O
# 3        O
# 4        O
#         ..
# 17769    O
# 17770    O
# 17771    O
# 17772    O
# 17773    O
# Name: cross_type, Length: 17774, dtype: object

# %%
pd.DataFrame(messages['Q'])
# Out:
#        stock_locate  tracking_number                    timestamp  shares  \
# 0              1880                3     b'\x1a1\x85\xcb\x1a\x0b'     317
# 1              5400                1  b'\x1f\x1a\xce\xe3\x81\xf1'       0
# 2              4268                1     b'\x1f\x1a\xce\xeb9\xd7'       0
# 3              1764                1  b'\x1f\x1a\xce\xef\x98\xe0'       0
# 4              2225                1     b'\x1f\x1a\xce\xfa?\x1f'       1
# ...             ...              ...                          ...     ...
# 17769           973                1  b'\x1f\x1b\x07\xa6\xd3\x0f'       0
# 17770          1024                1     b'\x1f\x1b\x07\xa86\x10'    3456
# 17771          6497                1     b'\x1f\x1b\x07\xa9I\xea'       0
# 17772          4356                1     b'\x1f\x1b\x07\xa9\xecg'       0
# 17773          8360                1     b'\x1f\x1b\x07\xab \x9f'       0
#
#              stock  cross_price  match_number cross_type
# 0      b'CYCN    '        94800         26943       b'H'
# 1      b'NBR-A   '            0         58610       b'O'
# 2      b'ITGR    '            0         58616       b'O'
# 3      b'CTAA    '            0         58620       b'O'
# 4      b'DWSH    '       256400         58628       b'O'
# ...            ...          ...           ...        ...
# 17769  b'BOCT    '            0        164210       b'O'
# 17770  b'BRKS    '       437100        164211       b'O'
# 17771  b'QADB    '            0        164213       b'O'
# 17772  b'JBN     '            0        164216       b'O'
# 17773  b'VIXY    '            0        164219       b'O'
#
# [17774 rows x 8 columns]

# %%
messages['P']
# Out:
# [P(stock_locate=4978, tracking_number=2, timestamp=b'\r\x1d\x8cO)B', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'MCHP    ', price=962700, match_number=17762),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\r H\xafH\xb3', order_reference_number=0, buy_sell_indicator=b'B', shares=20, stock=b'AAPL    ', price=2431200, match_number=17769),
#  P(stock_locate=4978, tracking_number=6, timestamp=b'\r \x98\x12h@', order_reference_number=0, buy_sell_indicator=b'B', shares=218, stock=b'MCHP    ', price=962700, match_number=17772),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\r$\xd1\x9e\xe9\x8d', order_reference_number=0, buy_sell_indicator=b'B', shares=1, stock=b'AAPL    ', price=2431200, match_number=17774),
#  P(stock_locate=8102, tracking_number=2, timestamp=b'\r(\x16\x8b\x92\x03', order_reference_number=0, buy_sell_indicator=b'B', shares=700, stock=b'UGAZ    ', price=156300, match_number=17788),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\r-X\xe5\xcfs', order_reference_number=0, buy_sell_indicator=b'B', shares=21, stock=b'AAPL    ', price=2431700, match_number=17796),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\r6\xedU\x00\xcf', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'AAPL    ', price=2432100, match_number=17807),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\r7\xbc\xd8k2', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'AAPL    ', price=2432100, match_number=17808),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\r995g\xa7', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'TSLA    ', price=3138500, match_number=17811),
#  P(stock_locate=7966, tracking_number=4, timestamp=b'\r995g\xa7', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'TSLA    ', price=3138700, match_number=17812),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\r9\xccR\xeam', order_reference_number=0, buy_sell_indicator=b'B', shares=500, stock=b'AAPL    ', price=2433000, match_number=17816),
#  P(stock_locate=13, tracking_number=4, timestamp=b'\r:\x081+\xbe', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'AAPL    ', price=2433000, match_number=17818),
#  P(stock_locate=7966, tracking_number=4, timestamp=b'\r;\xd4\xb5\n\xe8', order_reference_number=0, buy_sell_indicator=b'B', shares=17, stock=b'TSLA    ', price=3140000, match_number=17824),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\rA\xbf\xdc\xe0\xf6', order_reference_number=0, buy_sell_indicator=b'B', shares=5, stock=b'AAPL    ', price=2433000, match_number=17831),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\rKD\x8b8\xdf', order_reference_number=0, buy_sell_indicator=b'B', shares=131, stock=b'AAPL    ', price=2431200, match_number=17843),
#  P(stock_locate=13, tracking_number=4, timestamp=b'\rKD\x8b8\xdf', order_reference_number=0, buy_sell_indicator=b'B', shares=29, stock=b'AAPL    ', price=2430200, match_number=17844),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\rL\x9a\x0b\x17\x99', order_reference_number=0, buy_sell_indicator=b'B', shares=2, stock=b'AAPL    ', price=2430200, match_number=17845),
#  P(stock_locate=3451, tracking_number=2, timestamp=b'\rN\x88Z^\x1b', order_reference_number=0, buy_sell_indicator=b'B', shares=1, stock=b'GOOGL   ', price=12605200, match_number=17846),
#  P(stock_locate=8386, tracking_number=2, timestamp=b'\rO\n\x80\xed\xc5', order_reference_number=0, buy_sell_indicator=b'B', shares=200, stock=b'VNE     ', price=174000, match_number=17848),
#  P(stock_locate=8386, tracking_number=2, timestamp=b'\rO\n\x82\x12M', order_reference_number=0, buy_sell_indicator=b'B', shares=200, stock=b'VNE     ', price=174000, match_number=17849),
#  P(stock_locate=8386, tracking_number=2, timestamp=b'\rO\n\x8d\xac\xe7', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'VNE     ', price=174000, match_number=17850),
#  P(stock_locate=8386, tracking_number=2, timestamp=b'\rO\x0b\x0e\x06,', order_reference_number=0, buy_sell_indicator=b'B', shares=200, stock=b'VNE     ', price=174900, match_number=17851),
#  P(stock_locate=8386, tracking_number=2, timestamp=b'\rO\x0b\x0f\xb8\x0f', order_reference_number=0, buy_sell_indicator=b'B', shares=200, stock=b'VNE     ', price=174900, match_number=17852),
#  P(stock_locate=8386, tracking_number=2, timestamp=b'\rO\x0b\x18\xbe\xc7', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'VNE     ', price=174900, match_number=17853),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\rR\xddy\xe25', order_reference_number=0, buy_sell_indicator=b'B', shares=10, stock=b'TSLA    ', price=3125300, match_number=17854),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\rTS\x9c\x08\xe6', order_reference_number=0, buy_sell_indicator=b'B', shares=298, stock=b'T       ', price=380000, match_number=17855),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\rUe.g\x1e', order_reference_number=0, buy_sell_indicator=b'B', shares=90, stock=b'TSLA    ', price=3125300, match_number=17856),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\rV\xb7\x9f\x93\xa8', order_reference_number=0, buy_sell_indicator=b'B', shares=144, stock=b'T       ', price=380000, match_number=17862),
#  P(stock_locate=338, tracking_number=2, timestamp=b'\rX\xfeH\xb5\x02', order_reference_number=0, buy_sell_indicator=b'B', shares=5, stock=b'AMD     ', price=324900, match_number=17866),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\r`j\xf9\x8eh', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=17871),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\ra\x99$\xc9R', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=17877),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\rb\x9a\x024F', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'TSLA    ', price=3134600, match_number=17879),
#  P(stock_locate=7428, tracking_number=2, timestamp=b'\rb\xc1)fu', order_reference_number=0, buy_sell_indicator=b'B', shares=30, stock=b'SPY     ', price=3031600, match_number=17880),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\rb\xc7"4\xbd', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=17882),
#  P(stock_locate=338, tracking_number=2, timestamp=b'\rm-\xc9|\t', order_reference_number=0, buy_sell_indicator=b'B', shares=147, stock=b'AMD     ', price=324600, match_number=17896),
#  P(stock_locate=338, tracking_number=4, timestamp=b'\r\x80\x7f#\x19\xc0', order_reference_number=0, buy_sell_indicator=b'B', shares=17, stock=b'AMD     ', price=324000, match_number=17930),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\r\x8a/\x83\xf2\xfb', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'TSLA    ', price=3135200, match_number=17943),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\r\x8b\x8f\x91\xd3H', order_reference_number=0, buy_sell_indicator=b'B', shares=299, stock=b'T       ', price=380000, match_number=17949),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\r\x8b\x93\x8a\xdc\x97', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=17950),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\r\x8d\xd2\x88\xc8]', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'TSLA    ', price=3135200, match_number=17955),
#  P(stock_locate=4478, tracking_number=2, timestamp=b'\r\x8e\xbcT\xf3\x7f', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'JPM     ', price=1261500, match_number=17957),
#  P(stock_locate=338, tracking_number=2, timestamp=b'\r\x92\xe6\x85C"', order_reference_number=0, buy_sell_indicator=b'B', shares=183, stock=b'AMD     ', price=323400, match_number=17960),
#  P(stock_locate=338, tracking_number=4, timestamp=b'\r\x92\xe6\x85C"', order_reference_number=0, buy_sell_indicator=b'B', shares=217, stock=b'AMD     ', price=323300, match_number=17961),
#  P(stock_locate=338, tracking_number=2, timestamp=b'\r\x92\xe6\x85}\xf2', order_reference_number=0, buy_sell_indicator=b'B', shares=32, stock=b'AMD     ', price=323300, match_number=17962),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\r\x9c\xbfB\x97Z', order_reference_number=0, buy_sell_indicator=b'B', shares=300, stock=b'T       ', price=380000, match_number=17971),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\r\x9c\xbfa\x104', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=17972),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\r\x9d\xa9\xf5\x81\xf4', order_reference_number=0, buy_sell_indicator=b'B', shares=50, stock=b'TSLA    ', price=3135600, match_number=17973),
#  P(stock_locate=338, tracking_number=4, timestamp=b'\r\x9d\xb7\xcd\xbb\x80', order_reference_number=0, buy_sell_indicator=b'B', shares=1500, stock=b'AMD     ', price=323000, match_number=17975),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\r\x9f0\xe4rT', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=17979),
#  P(stock_locate=4946, tracking_number=2, timestamp=b'\r\xd0j\xc8\xe8\xf4', order_reference_number=0, buy_sell_indicator=b'B', shares=4, stock=b'MAT     ', price=124200, match_number=18061),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\r\xd8\xaa\xa9\x80\xaa', order_reference_number=0, buy_sell_indicator=b'B', shares=299, stock=b'T       ', price=380000, match_number=18068),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\r\xd9\xe1\x1cm\x10', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=18070),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\r\xdb\x0f\x14\xe6v', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=18072),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\r\xdc=\x0f\x83\x89', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=18073),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\r\xdc\xe4\x87U\xa6', order_reference_number=0, buy_sell_indicator=b'B', shares=299, stock=b'T       ', price=380000, match_number=18075),
#  P(stock_locate=8102, tracking_number=2, timestamp=b'\r\xe9`\xdd\xb0#', order_reference_number=0, buy_sell_indicator=b'B', shares=600, stock=b'UGAZ    ', price=158600, match_number=18083),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\r\xf5\xa4\xe63\xdf', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'BYND    ', price=838500, match_number=18090),
#  P(stock_locate=2754, tracking_number=7, timestamp=b'\x0e\x06\xa6\x9c\xc1\x1e', order_reference_number=0, buy_sell_indicator=b'B', shares=1562, stock=b'FCAU    ', price=141600, match_number=18101),
#  P(stock_locate=8102, tracking_number=2, timestamp=b'\x0e\x12\x85{\xa2\xa7', order_reference_number=0, buy_sell_indicator=b'B', shares=600, stock=b'UGAZ    ', price=158600, match_number=18108),
#  P(stock_locate=8102, tracking_number=2, timestamp=b'\x0e\x12\x85{\xd3\x9e', order_reference_number=0, buy_sell_indicator=b'B', shares=200, stock=b'UGAZ    ', price=158600, match_number=18109),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\x0e\x16X\xefj\xbd', order_reference_number=0, buy_sell_indicator=b'B', shares=300, stock=b'T       ', price=380000, match_number=18111),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\x0e\x16\xf3\xbd\xb5\xc2', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=18113),
#  P(stock_locate=8102, tracking_number=2, timestamp=b'\x0e:A\xab6\x05', order_reference_number=0, buy_sell_indicator=b'B', shares=300, stock=b'UGAZ    ', price=158700, match_number=18153),
#  P(stock_locate=3451, tracking_number=2, timestamp=b'\x0e\\\xd4H\xc5A', order_reference_number=0, buy_sell_indicator=b'B', shares=2, stock=b'GOOGL   ', price=12599500, match_number=18174),
#  P(stock_locate=3451, tracking_number=2, timestamp=b'\x0ev\xb1Q0\x7f', order_reference_number=0, buy_sell_indicator=b'B', shares=3, stock=b'GOOGL   ', price=12599500, match_number=18187),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\x0e\xbeW\xf9U\x8a', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=18222),
#  P(stock_locate=1151, tracking_number=4, timestamp=b'\x0e\xc5\x17\xef\x95\xda', order_reference_number=0, buy_sell_indicator=b'B', shares=15, stock=b'BYND    ', price=837500, match_number=18231),
#  P(stock_locate=1151, tracking_number=4, timestamp=b'\x0e\xea\xa0YW\x04', order_reference_number=0, buy_sell_indicator=b'B', shares=5, stock=b'BYND    ', price=837500, match_number=18265),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x0e\xed\x1c\x96\xe7\x02', order_reference_number=0, buy_sell_indicator=b'B', shares=50, stock=b'BYND    ', price=842500, match_number=18268),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\x0e\xfa*]Ub', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=18276),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\x0e\xfa+)\xa3\x8a', order_reference_number=0, buy_sell_indicator=b'B', shares=197, stock=b'T       ', price=380000, match_number=18277),
#  P(stock_locate=319, tracking_number=2, timestamp=b'\x0f(\x13\xe8\xaaF', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ALV     ', price=790000, match_number=18303),
#  P(stock_locate=868, tracking_number=2, timestamp=b'\x0f3\xbd\xe3\xa0P', order_reference_number=0, buy_sell_indicator=b'B', shares=300, stock=b'BIIB    ', price=3029800, match_number=18309),
#  P(stock_locate=338, tracking_number=2, timestamp=b'\x0fA \xad*H', order_reference_number=0, buy_sell_indicator=b'B', shares=200, stock=b'AMD     ', price=321200, match_number=18316),
#  P(stock_locate=338, tracking_number=4, timestamp=b'\x0fA \xad*H', order_reference_number=0, buy_sell_indicator=b'B', shares=140, stock=b'AMD     ', price=321200, match_number=18317),
#  P(stock_locate=8244, tracking_number=2, timestamp=b'\x0fC\x8fw\xcb\x91', order_reference_number=0, buy_sell_indicator=b'B', shares=50, stock=b'UVXY    ', price=199900, match_number=18318),
#  P(stock_locate=5255, tracking_number=4, timestamp=b'\x0fJ\x0b\xef\x12\xfe', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'MS      ', price=462500, match_number=18324),
#  P(stock_locate=3451, tracking_number=2, timestamp=b'\x0fKX0\x90"', order_reference_number=0, buy_sell_indicator=b'B', shares=13, stock=b'GOOGL   ', price=12599500, match_number=18327),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\x0fNa\xc2\xf2P', order_reference_number=0, buy_sell_indicator=b'B', shares=2, stock=b'TSLA    ', price=3136800, match_number=18329),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x0fe oH\x1c', order_reference_number=0, buy_sell_indicator=b'B', shares=150, stock=b'BYND    ', price=841900, match_number=18347),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\x0fk\x0b\x98\xd7\x9a', order_reference_number=0, buy_sell_indicator=b'B', shares=6, stock=b'TSLA    ', price=3136800, match_number=18356),
#  P(stock_locate=338, tracking_number=2, timestamp=b'\x0fqJ\xbf\x89\xbc', order_reference_number=0, buy_sell_indicator=b'B', shares=43, stock=b'AMD     ', price=321600, match_number=18371),
#  P(stock_locate=1151, tracking_number=6, timestamp=b'\x0f\x87s\xd1\x15\x0f', order_reference_number=0, buy_sell_indicator=b'B', shares=90, stock=b'BYND    ', price=842500, match_number=18400),
#  P(stock_locate=599, tracking_number=2, timestamp=b'\x0f\x8e\xb9\xa2\xc9!', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'AU      ', price=197800, match_number=18407),
#  P(stock_locate=1151, tracking_number=6, timestamp=b'\x0f\xa0\x9b\x03\xe5\xf7', order_reference_number=0, buy_sell_indicator=b'B', shares=90, stock=b'BYND    ', price=842500, match_number=18430),
#  P(stock_locate=1151, tracking_number=4, timestamp=b'\x0f\xa1\xd4I\xae\xdf', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'BYND    ', price=842500, match_number=18436),
#  P(stock_locate=338, tracking_number=4, timestamp=b'\x0f\xa3Z<\x1dU', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'AMD     ', price=320100, match_number=18438),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\x0f\xb1\xdaG%\xae', order_reference_number=0, buy_sell_indicator=b'B', shares=2, stock=b'TSLA    ', price=3136800, match_number=18464),
#  P(stock_locate=1151, tracking_number=4, timestamp=b'\x0f\xc7\xd42M\\', order_reference_number=0, buy_sell_indicator=b'B', shares=80, stock=b'BYND    ', price=842000, match_number=18495),
#  P(stock_locate=338, tracking_number=2, timestamp=b'\x0f\xc9"ZLy', order_reference_number=0, buy_sell_indicator=b'B', shares=50, stock=b'AMD     ', price=318200, match_number=18498),
#  P(stock_locate=338, tracking_number=2, timestamp=b'\x0f\xcd\x98\xc2\x07w', order_reference_number=0, buy_sell_indicator=b'B', shares=500, stock=b'AMD     ', price=318100, match_number=18503),
#  P(stock_locate=338, tracking_number=2, timestamp=b'\x0f\xce\xa7\xb2\x06\r', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'AMD     ', price=318100, match_number=18506),
#  P(stock_locate=338, tracking_number=4, timestamp=b'\x0f\xdd,[F\xee', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'AMD     ', price=318100, match_number=18516),
#  P(stock_locate=338, tracking_number=8, timestamp=b'\x0f\xeb\xedMQR', order_reference_number=0, buy_sell_indicator=b'B', shares=131, stock=b'AMD     ', price=318000, match_number=18549),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\x0f\xf2\xa3\xd0!\xba', order_reference_number=0, buy_sell_indicator=b'B', shares=127, stock=b'AAPL    ', price=2434900, match_number=18557),
#  P(stock_locate=8102, tracking_number=2, timestamp=b'\x10\x12\x9fa\x88_', order_reference_number=0, buy_sell_indicator=b'B', shares=553, stock=b'UGAZ    ', price=157500, match_number=18580),
#  P(stock_locate=338, tracking_number=8, timestamp=b'\x10\x1f\x9a:`\x07', order_reference_number=0, buy_sell_indicator=b'B', shares=70, stock=b'AMD     ', price=320000, match_number=18594),
#  P(stock_locate=338, tracking_number=2, timestamp=b'\x10!f\xba\r^', order_reference_number=0, buy_sell_indicator=b'B', shares=130, stock=b'AMD     ', price=320000, match_number=18595),
#  P(stock_locate=4946, tracking_number=2, timestamp=b'\x10(\xf9\xa4\x82\x8f', order_reference_number=0, buy_sell_indicator=b'B', shares=10, stock=b'MAT     ', price=124600, match_number=18602),
#  P(stock_locate=7966, tracking_number=4, timestamp=b'\x10,\xa4\x92\xd40', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'TSLA    ', price=3137300, match_number=18605),
#  P(stock_locate=7966, tracking_number=6, timestamp=b'\x10,\xa4\x92\xd40', order_reference_number=0, buy_sell_indicator=b'B', shares=82, stock=b'TSLA    ', price=3137200, match_number=18606),
#  P(stock_locate=5688, tracking_number=2, timestamp=b'\x10,\xb7\xe6p\xdb', order_reference_number=0, buy_sell_indicator=b'B', shares=40, stock=b'NVDA    ', price=2036800, match_number=18607),
#  P(stock_locate=338, tracking_number=2, timestamp=b'\x10,\xd4\xe9\x9e\x85', order_reference_number=0, buy_sell_indicator=b'B', shares=53, stock=b'AMD     ', price=321900, match_number=18608),
#  P(stock_locate=13, tracking_number=4, timestamp=b'\x10D\x06K\xc5u', order_reference_number=0, buy_sell_indicator=b'B', shares=28, stock=b'AAPL    ', price=2434900, match_number=18625),
#  P(stock_locate=3451, tracking_number=2, timestamp=b'\x10\\\x95\xea6t', order_reference_number=0, buy_sell_indicator=b'B', shares=2, stock=b'GOOGL   ', price=12597500, match_number=18633),
#  P(stock_locate=319, tracking_number=2, timestamp=b'\x10n\xc2\xcfm\xb1', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ALV     ', price=788000, match_number=18651),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\x10z_\x11\xd3\xf6', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'AAPL    ', price=2434900, match_number=18663),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\x10\x89\x85\xbf\xb7\x9c', order_reference_number=0, buy_sell_indicator=b'B', shares=11, stock=b'AAPL    ', price=2434900, match_number=18674),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\x10\xa6T\xc5$\xd7', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'TSLA    ', price=3141900, match_number=18706),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\x10\xc4M\x8d\xff\xa9', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'TSLA    ', price=3145200, match_number=18735),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\x10\xc7*\xaf7\x18', order_reference_number=0, buy_sell_indicator=b'B', shares=121, stock=b'TSLA    ', price=3148900, match_number=18737),
#  P(stock_locate=7966, tracking_number=4, timestamp=b'\x10\xc7*\xaf7\x18', order_reference_number=0, buy_sell_indicator=b'B', shares=82, stock=b'TSLA    ', price=3149500, match_number=18738),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\x10\xc8\xadU\x90\xb1', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'TSLA    ', price=3150200, match_number=18748),
#  P(stock_locate=855, tracking_number=2, timestamp=b'\x10\xf3\x94\x0f\x9a\xb6', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'BHP     ', price=490400, match_number=18770),
#  P(stock_locate=319, tracking_number=2, timestamp=b'\x10\xfa\x0c\xfel\xc6', order_reference_number=0, buy_sell_indicator=b'B', shares=200, stock=b'ALV     ', price=787000, match_number=18775),
#  P(stock_locate=319, tracking_number=2, timestamp=b'\x10\xfa\x1e\xeaUa', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ALV     ', price=787000, match_number=18776),
#  P(stock_locate=8838, tracking_number=2, timestamp=b'\x115\x1aT\x0b\xaa', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZEAL    ', price=281200, match_number=18815),
#  P(stock_locate=8838, tracking_number=2, timestamp=b'\x115\x1a`\x9a\xf9', order_reference_number=0, buy_sell_indicator=b'B', shares=200, stock=b'ZEAL    ', price=281200, match_number=18817),
#  P(stock_locate=3358, tracking_number=4, timestamp=b'\x11E\xe2\x86L\x05', order_reference_number=0, buy_sell_indicator=b'B', shares=1000, stock=b'GLD     ', price=1404900, match_number=18836),
#  P(stock_locate=3358, tracking_number=2, timestamp=b'\x11E\xe2\x86b\xcf', order_reference_number=0, buy_sell_indicator=b'B', shares=500, stock=b'GLD     ', price=1404900, match_number=18837),
#  P(stock_locate=855, tracking_number=2, timestamp=b'\x11\x84\xab\xe9\xcb\xea', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'BHP     ', price=489900, match_number=18896),
#  P(stock_locate=855, tracking_number=2, timestamp=b'\x11\x85\x1c\xb9\x16O', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'BHP     ', price=489900, match_number=18897),
#  P(stock_locate=5688, tracking_number=2, timestamp=b'\x11\x8b\x9c\x08\t`', order_reference_number=0, buy_sell_indicator=b'B', shares=70, stock=b'NVDA    ', price=2037200, match_number=18905),
#  P(stock_locate=8102, tracking_number=2, timestamp=b'\x11\x91\xca\xe1\xbcu', order_reference_number=0, buy_sell_indicator=b'B', shares=33, stock=b'UGAZ    ', price=158200, match_number=18908),
#  P(stock_locate=5688, tracking_number=2, timestamp=b'\x11\x9b\r\xf4?.', order_reference_number=0, buy_sell_indicator=b'B', shares=2, stock=b'NVDA    ', price=2037200, match_number=18911),
#  P(stock_locate=4456, tracking_number=2, timestamp=b'\x11\xa3F\xdb\x94B', order_reference_number=0, buy_sell_indicator=b'B', shares=200, stock=b'JNJ     ', price=1329700, match_number=18919),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x11\xb7\xfd#\x822', order_reference_number=0, buy_sell_indicator=b'B', shares=10, stock=b'BYND    ', price=845000, match_number=18932),
#  P(stock_locate=1151, tracking_number=8, timestamp=b'\x11\xb7\xfd#\x822', order_reference_number=0, buy_sell_indicator=b'B', shares=4, stock=b'BYND    ', price=842500, match_number=18935),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x11\xb9\xc5`?y', order_reference_number=0, buy_sell_indicator=b'B', shares=6, stock=b'BYND    ', price=842500, match_number=18937),
#  P(stock_locate=13, tracking_number=2, timestamp=b"\x11\xcf\x82\xe4'K", order_reference_number=0, buy_sell_indicator=b'B', shares=20, stock=b'AAPL    ', price=2434900, match_number=18956),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x11\xd4l\x96\xf3\x8f', order_reference_number=0, buy_sell_indicator=b'B', shares=17, stock=b'BYND    ', price=846700, match_number=18961),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\x11\xe8\x8b\xda\x92\xe6', order_reference_number=0, buy_sell_indicator=b'B', shares=27, stock=b'AAPL    ', price=2434900, match_number=18974),
#  P(stock_locate=3451, tracking_number=2, timestamp=b'\x11\xf2\xa9\x1b-\x11', order_reference_number=0, buy_sell_indicator=b'B', shares=30, stock=b'GOOGL   ', price=12597300, match_number=18987),
#  P(stock_locate=3451, tracking_number=4, timestamp=b'\x11\xf2\xa9\x1b-\x11', order_reference_number=0, buy_sell_indicator=b'B', shares=37, stock=b'GOOGL   ', price=12597500, match_number=18988),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\x12\x08H:9_', order_reference_number=0, buy_sell_indicator=b'B', shares=188, stock=b'T       ', price=380000, match_number=19018),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\x12\t\x17\xd7\xc1\xf2', order_reference_number=0, buy_sell_indicator=b'B', shares=220, stock=b'T       ', price=380000, match_number=19019),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\x12\x13\xd4m\xcah', order_reference_number=0, buy_sell_indicator=b'B', shares=2, stock=b'AAPL    ', price=2434900, match_number=19024),
#  P(stock_locate=2733, tracking_number=4, timestamp=b'\x12+\xe0d\xa4\xf6', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'FB      ', price=1895600, match_number=19057),
#  P(stock_locate=6020, tracking_number=2, timestamp=b'\x12\x8fG\xba?\xd6', order_reference_number=0, buy_sell_indicator=b'B', shares=19, stock=b'PCG     ', price=54800, match_number=19153),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x12\xa3{Ig9', order_reference_number=0, buy_sell_indicator=b'B', shares=20, stock=b'BYND    ', price=845500, match_number=19167),
#  P(stock_locate=1151, tracking_number=4, timestamp=b'\x12\xa3{Ig9', order_reference_number=0, buy_sell_indicator=b'B', shares=200, stock=b'BYND    ', price=845400, match_number=19168),
#  P(stock_locate=8744, tracking_number=2, timestamp=b'\x12\xd0\xe7*\xd5*', order_reference_number=0, buy_sell_indicator=b'B', shares=3, stock=b'XNET    ', price=47000, match_number=19184),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\x12\xd1\t\xc5}\x97', order_reference_number=0, buy_sell_indicator=b'B', shares=155, stock=b'T       ', price=380000, match_number=19185),
#  P(stock_locate=855, tracking_number=2, timestamp=b'\x12\xdbQqk\xea', order_reference_number=0, buy_sell_indicator=b'B', shares=90, stock=b'BHP     ', price=487900, match_number=19190),
#  P(stock_locate=855, tracking_number=2, timestamp=b'\x12\xdbQz\xddY', order_reference_number=0, buy_sell_indicator=b'B', shares=90, stock=b'BHP     ', price=487900, match_number=19191),
#  P(stock_locate=8744, tracking_number=2, timestamp=b'\x12\xed\xa59)\xb1', order_reference_number=0, buy_sell_indicator=b'B', shares=13, stock=b'XNET    ', price=47000, match_number=19206),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\x12\xfaB\x15\x9ff', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'AAPL    ', price=2437900, match_number=19225),
#  P(stock_locate=13, tracking_number=4, timestamp=b'\x12\xfef\x171\xe5', order_reference_number=0, buy_sell_indicator=b'B', shares=807, stock=b'AAPL    ', price=2437900, match_number=19236),
#  P(stock_locate=7966, tracking_number=4, timestamp=b'\x13\x0b\x14I\xc3\xea', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'TSLA    ', price=3145600, match_number=19257),
#  P(stock_locate=7966, tracking_number=6, timestamp=b'\x13\x0b\x14I\xc3\xea', order_reference_number=0, buy_sell_indicator=b'B', shares=30, stock=b'TSLA    ', price=3143600, match_number=19258),
#  P(stock_locate=8744, tracking_number=2, timestamp=b'\x13\x0c\xc9j\xbe\x07', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'XNET    ', price=47000, match_number=19259),
#  P(stock_locate=338, tracking_number=2, timestamp=b'\x13\x15\xd0.m1', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'AMD     ', price=321900, match_number=19267),
#  P(stock_locate=338, tracking_number=2, timestamp=b'\x13\x16\xe1-\x18i', order_reference_number=0, buy_sell_indicator=b'B', shares=47, stock=b'AMD     ', price=321900, match_number=19269),
#  P(stock_locate=3758, tracking_number=2, timestamp=b'\x13\x18@|R\xc3', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'HMY     ', price=33200, match_number=19271),
#  P(stock_locate=3758, tracking_number=2, timestamp=b'\x13\x18\xf7=\xe6I', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'HMY     ', price=33200, match_number=19272),
#  P(stock_locate=3758, tracking_number=2, timestamp=b'\x13\x19\xae\x0b3\x8b', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'HMY     ', price=33200, match_number=19274),
#  P(stock_locate=3758, tracking_number=2, timestamp=b'\x13\x1ad\xccE*', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'HMY     ', price=33200, match_number=19275),
#  P(stock_locate=3758, tracking_number=2, timestamp=b'\x13\x1b\x1b\x90\xaa\x9a', order_reference_number=0, buy_sell_indicator=b'B', shares=92, stock=b'HMY     ', price=33200, match_number=19276),
#  P(stock_locate=8744, tracking_number=2, timestamp=b'\x13$\xcee\x02\xf5', order_reference_number=0, buy_sell_indicator=b'B', shares=384, stock=b'XNET    ', price=47000, match_number=19278),
#  P(stock_locate=2033, tracking_number=4, timestamp=b'\x13*j\xf4\x9f\xc0', order_reference_number=0, buy_sell_indicator=b'B', shares=850, stock=b'DIS     ', price=1294000, match_number=19282),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\x138\xf8\xd3\xc2\x02', order_reference_number=0, buy_sell_indicator=b'B', shares=2, stock=b'TSLA    ', price=3150300, match_number=19293),
#  P(stock_locate=7966, tracking_number=4, timestamp=b'\x138\xf8\xd3\xc2\x02', order_reference_number=0, buy_sell_indicator=b'B', shares=2, stock=b'TSLA    ', price=3150300, match_number=19294),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\x13:\xc9\xf7\x0e:', order_reference_number=0, buy_sell_indicator=b'B', shares=30, stock=b'TSLA    ', price=3150200, match_number=19295),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\x13;k\xc5\x9b\xbc', order_reference_number=0, buy_sell_indicator=b'B', shares=4, stock=b'TSLA    ', price=3150200, match_number=19296),
#  P(stock_locate=3451, tracking_number=2, timestamp=b'\x13?\xbd\xa2q:', order_reference_number=0, buy_sell_indicator=b'B', shares=15, stock=b'GOOGL   ', price=12597000, match_number=19298),
#  P(stock_locate=3451, tracking_number=4, timestamp=b'\x13?\xbd\xa2q:', order_reference_number=0, buy_sell_indicator=b'B', shares=115, stock=b'GOOGL   ', price=12597500, match_number=19299),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\x13A\xc8\xb3\xf1\x10', order_reference_number=0, buy_sell_indicator=b'B', shares=2, stock=b'TSLA    ', price=3150300, match_number=19301),
#  P(stock_locate=7966, tracking_number=4, timestamp=b'\x13A\xc8\xb3\xf1\x10', order_reference_number=0, buy_sell_indicator=b'B', shares=16, stock=b'TSLA    ', price=3150300, match_number=19302),
#  P(stock_locate=3451, tracking_number=2, timestamp=b'\x13QO\xc7\xa3\xd9', order_reference_number=0, buy_sell_indicator=b'B', shares=15, stock=b'GOOGL   ', price=12597500, match_number=19328),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x13\x82\xb0\xb5\xba0', order_reference_number=0, buy_sell_indicator=b'B', shares=10, stock=b'BYND    ', price=840500, match_number=19361),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x13\x82\xb1W\x1a\xc6', order_reference_number=0, buy_sell_indicator=b'B', shares=3, stock=b'BYND    ', price=840500, match_number=19362),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x13\x87\xf6v\xaf\n', order_reference_number=0, buy_sell_indicator=b'B', shares=7, stock=b'BYND    ', price=840500, match_number=19368),
#  P(stock_locate=4619, tracking_number=2, timestamp=b'\x13\xb69\xfa=\xae', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'KO      ', price=535100, match_number=19390),
#  P(stock_locate=3268, tracking_number=4, timestamp=b'\x13\xb8V\x81\x8f\xc1', order_reference_number=0, buy_sell_indicator=b'B', shares=2000, stock=b'GE      ', price=93300, match_number=19399),
#  P(stock_locate=338, tracking_number=6, timestamp=b'\x13\xb9\xce{\xfcb', order_reference_number=0, buy_sell_indicator=b'B', shares=1, stock=b'AMD     ', price=322000, match_number=19408),
#  P(stock_locate=4619, tracking_number=2, timestamp=b'\x13\xbfm\x8f\xa5\xb3', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'KO      ', price=535200, match_number=19418),
#  P(stock_locate=338, tracking_number=6, timestamp=b'\x13\xc1\xfd4\xc3\x0e', order_reference_number=0, buy_sell_indicator=b'B', shares=1431, stock=b'AMD     ', price=323000, match_number=19421),
#  P(stock_locate=8004, tracking_number=4, timestamp=b'\x13\xce\x9d\xe5\xccV', order_reference_number=0, buy_sell_indicator=b'B', shares=900, stock=b'TVIX    ', price=95100, match_number=19443),
#  P(stock_locate=7629, tracking_number=2, timestamp=b"\x13\xde'-9\xed", order_reference_number=0, buy_sell_indicator=b'B', shares=150, stock=b'T       ', price=380000, match_number=19459),
#  P(stock_locate=3268, tracking_number=4, timestamp=b'\x13\xe1\xec\xaa\xd9\xc2', order_reference_number=0, buy_sell_indicator=b'B', shares=463, stock=b'GE      ', price=92500, match_number=19471),
#  P(stock_locate=3268, tracking_number=4, timestamp=b'\x13\xe7e\xf5\x95N', order_reference_number=0, buy_sell_indicator=b'B', shares=37, stock=b'GE      ', price=92500, match_number=19481),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\x13\xfd\xab\xd0\x02\xc7', order_reference_number=0, buy_sell_indicator=b'B', shares=250, stock=b'T       ', price=380000, match_number=19491),
#  P(stock_locate=1671, tracking_number=2, timestamp=b'\x14\x01@\x19\xf4\xa9', order_reference_number=0, buy_sell_indicator=b'B', shares=1, stock=b'CPRX    ', price=52800, match_number=19495),
#  P(stock_locate=3268, tracking_number=2, timestamp=b'\x14\r\x93\xb9o\xbe', order_reference_number=0, buy_sell_indicator=b'B', shares=2, stock=b'GE      ', price=93700, match_number=19511),
#  P(stock_locate=6020, tracking_number=2, timestamp=b'\x14\x0e\xdb\x17\xc2\xf9', order_reference_number=0, buy_sell_indicator=b'B', shares=270, stock=b'PCG     ', price=54800, match_number=19516),
#  P(stock_locate=6020, tracking_number=4, timestamp=b'\x14\x0e\xdb\x17\xc2\xf9', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'PCG     ', price=54900, match_number=19517),
#  P(stock_locate=6020, tracking_number=8, timestamp=b'\x14\x0e\xdb\x17\xc2\xf9', order_reference_number=0, buy_sell_indicator=b'B', shares=530, stock=b'PCG     ', price=55000, match_number=19519),
#  P(stock_locate=1671, tracking_number=2, timestamp=b'\x14\x12h\xa2\xa21', order_reference_number=0, buy_sell_indicator=b'B', shares=5, stock=b'CPRX    ', price=52500, match_number=19522),
#  P(stock_locate=8004, tracking_number=2, timestamp=b'\x14\x1b\xd7\x91#\xa0', order_reference_number=0, buy_sell_indicator=b'B', shares=400, stock=b'TVIX    ', price=94900, match_number=19540),
#  P(stock_locate=338, tracking_number=2, timestamp=b'\x140\xf5\x1ebv', order_reference_number=0, buy_sell_indicator=b'B', shares=1000, stock=b'AMD     ', price=322500, match_number=19576),
#  P(stock_locate=338, tracking_number=2, timestamp=b'\x141\xe7\x02\x9fR', order_reference_number=0, buy_sell_indicator=b'B', shares=1000, stock=b'AMD     ', price=322500, match_number=19578),
#  P(stock_locate=3268, tracking_number=2, timestamp=b'\x143\xc4+V\xd9', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'GE      ', price=94600, match_number=19586),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\x148\xef\xa8\xe0\xea', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=19592),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\x149\x1bS\x1e\xf4', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=19593),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\x149\x1b_\x16\xf6', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=19594),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\x149\x1bj\xdb\xad', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=19595),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\x149\x1f\xae\xca\xd6', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=19596),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\x14:\x98N}\x86', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=19598),
#  P(stock_locate=1996, tracking_number=4, timestamp=b'\x14:\xab\xbf"m', order_reference_number=0, buy_sell_indicator=b'B', shares=198, stock=b'DGAZ    ', price=1140500, match_number=19600),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\x14:\xce@;\xea', order_reference_number=0, buy_sell_indicator=b'B', shares=250, stock=b'T       ', price=380000, match_number=19601),
#  P(stock_locate=7906, tracking_number=2, timestamp=b'\x14i\xa19\x04a', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'TQQQ    ', price=683000, match_number=19666),
#  P(stock_locate=8102, tracking_number=4, timestamp=b'\x14qW\xc7@\xae', order_reference_number=0, buy_sell_indicator=b'B', shares=400, stock=b'UGAZ    ', price=161200, match_number=19677),
#  P(stock_locate=8102, tracking_number=4, timestamp=b'\x14\x80\xba\xaco\x1c', order_reference_number=0, buy_sell_indicator=b'B', shares=400, stock=b'UGAZ    ', price=161000, match_number=19688),
#  P(stock_locate=3502, tracking_number=2, timestamp=b'\x14\x80\xf4\xe7\xf5\xcf', order_reference_number=0, buy_sell_indicator=b'B', shares=20, stock=b'GRUB    ', price=331100, match_number=19692),
#  P(stock_locate=8879, tracking_number=6, timestamp=b'\x14\x84\xe4z\xf0\x06', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19793),
#  P(stock_locate=8879, tracking_number=8, timestamp=b'\x14\x84\xe4z\xf0\x06', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19794),
#  P(stock_locate=8879, tracking_number=10, timestamp=b'\x14\x84\xe4z\xf0\x06', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19795),
#  P(stock_locate=8879, tracking_number=12, timestamp=b'\x14\x84\xe4z\xf0\x06', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19796),
#  P(stock_locate=8879, tracking_number=14, timestamp=b'\x14\x84\xe4z\xf0\x06', order_reference_number=0, buy_sell_indicator=b'B', shares=10, stock=b'ZVZZT   ', price=100000, match_number=19797),
#  P(stock_locate=8879, tracking_number=2, timestamp=b'\x14\x84\xe4\x98Em', order_reference_number=0, buy_sell_indicator=b'B', shares=90, stock=b'ZVZZT   ', price=100000, match_number=19798),
#  P(stock_locate=8879, tracking_number=4, timestamp=b'\x14\x84\xe4\x98Em', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19799),
#  P(stock_locate=8879, tracking_number=6, timestamp=b'\x14\x84\xe4\x98Em', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19800),
#  P(stock_locate=8879, tracking_number=8, timestamp=b'\x14\x84\xe4\x98Em', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19801),
#  P(stock_locate=8879, tracking_number=10, timestamp=b'\x14\x84\xe4\x98Em', order_reference_number=0, buy_sell_indicator=b'B', shares=10, stock=b'ZVZZT   ', price=100000, match_number=19802),
#  P(stock_locate=8879, tracking_number=2, timestamp=b'\x14\x84\xe4\xbbe}', order_reference_number=0, buy_sell_indicator=b'B', shares=90, stock=b'ZVZZT   ', price=100000, match_number=19803),
#  P(stock_locate=8879, tracking_number=4, timestamp=b'\x14\x84\xe4\xbbe}', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19804),
#  P(stock_locate=8879, tracking_number=6, timestamp=b'\x14\x84\xe4\xbbe}', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19805),
#  P(stock_locate=8879, tracking_number=8, timestamp=b'\x14\x84\xe4\xbbe}', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19806),
#  P(stock_locate=8879, tracking_number=10, timestamp=b'\x14\x84\xe4\xbbe}', order_reference_number=0, buy_sell_indicator=b'B', shares=10, stock=b'ZVZZT   ', price=100000, match_number=19807),
#  P(stock_locate=8879, tracking_number=2, timestamp=b'\x14\x84\xe4\xc7\xc2\xee', order_reference_number=0, buy_sell_indicator=b'B', shares=90, stock=b'ZVZZT   ', price=100000, match_number=19808),
#  P(stock_locate=8879, tracking_number=4, timestamp=b'\x14\x84\xe4\xc7\xc2\xee', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19809),
#  P(stock_locate=8879, tracking_number=6, timestamp=b'\x14\x84\xe4\xc7\xc2\xee', order_reference_number=0, buy_sell_indicator=b'B', shares=10, stock=b'ZVZZT   ', price=100000, match_number=19810),
#  P(stock_locate=8879, tracking_number=2, timestamp=b'\x14\x84\xe4\xd8\x84\xff', order_reference_number=0, buy_sell_indicator=b'B', shares=90, stock=b'ZVZZT   ', price=100000, match_number=19811),
#  P(stock_locate=8879, tracking_number=4, timestamp=b'\x14\x84\xe4\xd8\x84\xff', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19812),
#  P(stock_locate=8879, tracking_number=6, timestamp=b'\x14\x84\xe4\xd8\x84\xff', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19813),
#  P(stock_locate=8879, tracking_number=8, timestamp=b'\x14\x84\xe4\xd8\x84\xff', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19814),
#  P(stock_locate=8879, tracking_number=10, timestamp=b'\x14\x84\xe4\xd8\x84\xff', order_reference_number=0, buy_sell_indicator=b'B', shares=10, stock=b'ZVZZT   ', price=100000, match_number=19815),
#  P(stock_locate=8879, tracking_number=2, timestamp=b'\x14\x84\xe4\xe97\xe4', order_reference_number=0, buy_sell_indicator=b'B', shares=90, stock=b'ZVZZT   ', price=100000, match_number=19816),
#  P(stock_locate=8879, tracking_number=4, timestamp=b'\x14\x84\xe4\xe97\xe4', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19817),
#  P(stock_locate=8879, tracking_number=6, timestamp=b'\x14\x84\xe4\xe97\xe4', order_reference_number=0, buy_sell_indicator=b'B', shares=10, stock=b'ZVZZT   ', price=100000, match_number=19818),
#  P(stock_locate=8879, tracking_number=2, timestamp=b'\x14\x84\xe4\xfb\x96\xa9', order_reference_number=0, buy_sell_indicator=b'B', shares=90, stock=b'ZVZZT   ', price=100000, match_number=19819),
#  P(stock_locate=8879, tracking_number=4, timestamp=b'\x14\x84\xe4\xfb\x96\xa9', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19820),
#  P(stock_locate=8879, tracking_number=6, timestamp=b'\x14\x84\xe4\xfb\x96\xa9', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19821),
#  P(stock_locate=8879, tracking_number=8, timestamp=b'\x14\x84\xe4\xfb\x96\xa9', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19822),
#  P(stock_locate=8879, tracking_number=10, timestamp=b'\x14\x84\xe4\xfb\x96\xa9', order_reference_number=0, buy_sell_indicator=b'B', shares=10, stock=b'ZVZZT   ', price=100000, match_number=19823),
#  P(stock_locate=8879, tracking_number=2, timestamp=b'\x14\x84\xe4\xfc\t\x81', order_reference_number=0, buy_sell_indicator=b'B', shares=90, stock=b'ZVZZT   ', price=100000, match_number=19824),
#  P(stock_locate=8879, tracking_number=4, timestamp=b'\x14\x84\xe4\xfc\t\x81', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19825),
#  P(stock_locate=8879, tracking_number=6, timestamp=b'\x14\x84\xe4\xfc\t\x81', order_reference_number=0, buy_sell_indicator=b'B', shares=10, stock=b'ZVZZT   ', price=100000, match_number=19826),
#  P(stock_locate=8879, tracking_number=2, timestamp=b'\x14\x84\xe5\x01\xad\r', order_reference_number=0, buy_sell_indicator=b'B', shares=90, stock=b'ZVZZT   ', price=100000, match_number=19827),
#  P(stock_locate=8879, tracking_number=4, timestamp=b'\x14\x84\xe5\x01\xad\r', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19828),
#  P(stock_locate=8879, tracking_number=6, timestamp=b'\x14\x84\xe5\x01\xad\r', order_reference_number=0, buy_sell_indicator=b'B', shares=10, stock=b'ZVZZT   ', price=100000, match_number=19829),
#  P(stock_locate=8879, tracking_number=2, timestamp=b'\x14\x84\xe5 >\x19', order_reference_number=0, buy_sell_indicator=b'B', shares=90, stock=b'ZVZZT   ', price=100000, match_number=19830),
#  P(stock_locate=8879, tracking_number=4, timestamp=b'\x14\x84\xe5 >\x19', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19831),
#  P(stock_locate=8879, tracking_number=6, timestamp=b'\x14\x84\xe5 >\x19', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19832),
#  P(stock_locate=8879, tracking_number=8, timestamp=b'\x14\x84\xe5 >\x19', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19833),
#  P(stock_locate=8879, tracking_number=10, timestamp=b'\x14\x84\xe5 >\x19', order_reference_number=0, buy_sell_indicator=b'B', shares=10, stock=b'ZVZZT   ', price=100000, match_number=19834),
#  P(stock_locate=8879, tracking_number=2, timestamp=b'\x14\x84\xe5"\x83#', order_reference_number=0, buy_sell_indicator=b'B', shares=90, stock=b'ZVZZT   ', price=100000, match_number=19835),
#  P(stock_locate=8879, tracking_number=4, timestamp=b'\x14\x84\xe5"\x83#', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19836),
#  P(stock_locate=8879, tracking_number=6, timestamp=b'\x14\x84\xe5"\x83#', order_reference_number=0, buy_sell_indicator=b'B', shares=10, stock=b'ZVZZT   ', price=100000, match_number=19837),
#  P(stock_locate=8879, tracking_number=2, timestamp=b'\x14\x84\xe5#\x96\xa2', order_reference_number=0, buy_sell_indicator=b'B', shares=90, stock=b'ZVZZT   ', price=100000, match_number=19838),
#  P(stock_locate=8879, tracking_number=4, timestamp=b'\x14\x84\xe5#\x96\xa2', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19839),
# ...
#  P(stock_locate=13, tracking_number=6, timestamp=b'\x19\t87\xf2.', order_reference_number=0, buy_sell_indicator=b'B', shares=49, stock=b'AAPL    ', price=2440700, match_number=24263),
#  P(stock_locate=1822, tracking_number=4, timestamp=b'\x19\n\r\x85\x11o', order_reference_number=0, buy_sell_indicator=b'B', shares=42, stock=b'CUR     ', price=17700, match_number=24271),
#  P(stock_locate=324, tracking_number=4, timestamp=b'\x19\nF\x1aoH', order_reference_number=0, buy_sell_indicator=b'B', shares=4600, stock=b'AMAG    ', price=100100, match_number=24273),
#  P(stock_locate=324, tracking_number=10, timestamp=b'\x19\nF\x1aoH', order_reference_number=0, buy_sell_indicator=b'B', shares=2600, stock=b'AMAG    ', price=100000, match_number=24276),
#  P(stock_locate=324, tracking_number=4, timestamp=b'\x19\nw\xaf\x84_', order_reference_number=0, buy_sell_indicator=b'B', shares=400, stock=b'AMAG    ', price=100000, match_number=24279),
#  P(stock_locate=2033, tracking_number=2, timestamp=b'\x19\x0c?\x078-', order_reference_number=0, buy_sell_indicator=b'B', shares=1, stock=b'DIS     ', price=1295500, match_number=24284),
#  P(stock_locate=1822, tracking_number=2, timestamp=b'\x19\x0c\xb2\x8f\xdb\xf6', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'CUR     ', price=17700, match_number=24287),
#  P(stock_locate=324, tracking_number=2, timestamp=b'\x19\r\x148\x03?', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'AMAG    ', price=100100, match_number=24290),
#  P(stock_locate=1822, tracking_number=2, timestamp=b'\x19\r\xce\x1br\xa1', order_reference_number=0, buy_sell_indicator=b'B', shares=17, stock=b'CUR     ', price=17700, match_number=24292),
#  P(stock_locate=7612, tracking_number=2, timestamp=b'\x19\x0e\x93\xf1\xcb[', order_reference_number=0, buy_sell_indicator=b'B', shares=2, stock=b'SYK     ', price=2130500, match_number=24297),
#  P(stock_locate=1822, tracking_number=2, timestamp=b'\x19\x0e\x94H\xd48', order_reference_number=0, buy_sell_indicator=b'B', shares=17, stock=b'CUR     ', price=17700, match_number=24298),
#  P(stock_locate=2754, tracking_number=6, timestamp=b'\x19\x0f\xb9XcN', order_reference_number=0, buy_sell_indicator=b'B', shares=456, stock=b'FCAU    ', price=142900, match_number=24302),
#  P(stock_locate=6020, tracking_number=2, timestamp=b'\x19\x0f\xf0\xcc\xff)', order_reference_number=0, buy_sell_indicator=b'B', shares=10, stock=b'PCG     ', price=60400, match_number=24303),
#  P(stock_locate=6020, tracking_number=2, timestamp=b'\x19\x0f\xf0\xcfV\xab', order_reference_number=0, buy_sell_indicator=b'B', shares=190, stock=b'PCG     ', price=60400, match_number=24304),
#  P(stock_locate=2754, tracking_number=6, timestamp=b'\x19\x10{z;\xd6', order_reference_number=0, buy_sell_indicator=b'B', shares=1300, stock=b'FCAU    ', price=142900, match_number=24309),
#  P(stock_locate=1822, tracking_number=2, timestamp=b'\x19\x11\x91\xf9\xa7\x9a', order_reference_number=0, buy_sell_indicator=b'B', shares=24, stock=b'CUR     ', price=17700, match_number=24315),
#  P(stock_locate=1822, tracking_number=4, timestamp=b'\x19\x11\xc2\xd5\xf9T', order_reference_number=0, buy_sell_indicator=b'B', shares=76, stock=b'CUR     ', price=17800, match_number=24321),
#  P(stock_locate=2754, tracking_number=6, timestamp=b'\x19\x12\x1c\x98\x1e\x8e', order_reference_number=0, buy_sell_indicator=b'B', shares=900, stock=b'FCAU    ', price=142900, match_number=24326),
#  P(stock_locate=3450, tracking_number=2, timestamp=b'\x19\x14A5\xab\xd5', order_reference_number=0, buy_sell_indicator=b'B', shares=25, stock=b'GOOG    ', price=12608500, match_number=24339),
#  P(stock_locate=3502, tracking_number=4, timestamp=b'\x19\x16_\x13\t ', order_reference_number=0, buy_sell_indicator=b'B', shares=13, stock=b'GRUB    ', price=318000, match_number=24350),
#  P(stock_locate=3450, tracking_number=2, timestamp=b'\x19\x18\x0ebO\xc6', order_reference_number=0, buy_sell_indicator=b'B', shares=40, stock=b'GOOG    ', price=12601900, match_number=24363),
#  P(stock_locate=1822, tracking_number=2, timestamp=b'\x19\x18\xacvs\x17', order_reference_number=0, buy_sell_indicator=b'B', shares=300, stock=b'CUR     ', price=17700, match_number=24369),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x19\x18\xe64\xea\x10', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'BYND    ', price=826100, match_number=24371),
#  P(stock_locate=2734, tracking_number=2, timestamp=b'\x19\x19-\x1fA\x89', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'FBC     ', price=364000, match_number=24372),
#  P(stock_locate=1822, tracking_number=2, timestamp=b'\x19\x19\xba\xa5\xf3\x8e', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'CUR     ', price=17700, match_number=24377),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x19\x1a(\x8cZ\xf9', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'BYND    ', price=826900, match_number=24378),
#  P(stock_locate=324, tracking_number=2, timestamp=b'\x19\x1a(\xb0Hp', order_reference_number=0, buy_sell_indicator=b'B', shares=199, stock=b'AMAG    ', price=100100, match_number=24379),
#  P(stock_locate=324, tracking_number=2, timestamp=b'\x19\x1a(\xbc\xde\xee', order_reference_number=0, buy_sell_indicator=b'B', shares=39, stock=b'AMAG    ', price=100100, match_number=24380),
#  P(stock_locate=2754, tracking_number=2, timestamp=b'\x19\x1a\xac3\t\xfc', order_reference_number=0, buy_sell_indicator=b'B', shares=200, stock=b'FCAU    ', price=142800, match_number=24387),
#  P(stock_locate=2754, tracking_number=4, timestamp=b'\x19\x1a\xac3j\x8e', order_reference_number=0, buy_sell_indicator=b'B', shares=1100, stock=b'FCAU    ', price=142800, match_number=24389),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x19\x1c\xa7\x81\x15\x9a', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'BYND    ', price=826900, match_number=24421),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x19\x1dYFh\x05', order_reference_number=0, buy_sell_indicator=b'B', shares=60, stock=b'BYND    ', price=826900, match_number=24424),
#  P(stock_locate=2734, tracking_number=2, timestamp=b'\x19\x1d}}\xba\xdd', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'FBC     ', price=364000, match_number=24425),
#  P(stock_locate=3502, tracking_number=4, timestamp=b'\x19\x1d\xc3K\x92\x92', order_reference_number=0, buy_sell_indicator=b'B', shares=400, stock=b'GRUB    ', price=320100, match_number=24427),
#  P(stock_locate=324, tracking_number=2, timestamp=b'\x19\x1e\t\x0bqV', order_reference_number=0, buy_sell_indicator=b'B', shares=63, stock=b'AMAG    ', price=100100, match_number=24428),
#  P(stock_locate=3502, tracking_number=4, timestamp=b'\x19\x1e9\x14\x98\x16', order_reference_number=0, buy_sell_indicator=b'B', shares=395, stock=b'GRUB    ', price=320100, match_number=24432),
#  P(stock_locate=6020, tracking_number=6, timestamp=b'\x19\x1f\x9bT\xaf\xa8', order_reference_number=0, buy_sell_indicator=b'B', shares=999, stock=b'PCG     ', price=60000, match_number=24441),
#  P(stock_locate=6020, tracking_number=2, timestamp=b'\x19\x1f\x9bT\xec\xbd', order_reference_number=0, buy_sell_indicator=b'B', shares=501, stock=b'PCG     ', price=60000, match_number=24442),
#  P(stock_locate=6020, tracking_number=4, timestamp=b'\x19\x1f\x9bT\xec\xbd', order_reference_number=0, buy_sell_indicator=b'B', shares=1100, stock=b'PCG     ', price=60000, match_number=24443),
#  P(stock_locate=1493, tracking_number=4, timestamp=b'\x19"\xcf\xcfq\x84', order_reference_number=0, buy_sell_indicator=b'B', shares=500, stock=b'CLLS    ', price=110200, match_number=24465),
#  P(stock_locate=6399, tracking_number=2, timestamp=b'\x19%\xb8A\xbd\xcc', order_reference_number=0, buy_sell_indicator=b'B', shares=50, stock=b'PSMT    ', price=726000, match_number=24479),
#  P(stock_locate=3256, tracking_number=2, timestamp=b'\x19&~A\x916', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'GDOT    ', price=322000, match_number=24486),
#  P(stock_locate=3256, tracking_number=4, timestamp=b'\x19&~A\x916', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'GDOT    ', price=321700, match_number=24487),
#  P(stock_locate=3256, tracking_number=8, timestamp=b'\x19&~A\x916', order_reference_number=0, buy_sell_indicator=b'B', shares=300, stock=b'GDOT    ', price=321500, match_number=24489),
#  P(stock_locate=3256, tracking_number=2, timestamp=b'\x19&~A\xa3>', order_reference_number=0, buy_sell_indicator=b'B', shares=400, stock=b'GDOT    ', price=321500, match_number=24490),
#  P(stock_locate=6020, tracking_number=2, timestamp=b'\x19&\x99\xddF\xa5', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'PCG     ', price=59700, match_number=24492),
#  P(stock_locate=338, tracking_number=4, timestamp=b'\x19)\x08\x93\x8d\xba', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'AMD     ', price=328900, match_number=24508),
#  P(stock_locate=338, tracking_number=2, timestamp=b'\x19)\x08\x93\xc9\xd6', order_reference_number=0, buy_sell_indicator=b'B', shares=200, stock=b'AMD     ', price=328900, match_number=24509),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x19*\xa4\xf9w\x86', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'BYND    ', price=826900, match_number=24524),
#  P(stock_locate=4456, tracking_number=2, timestamp=b'\x19+-o\xf6h', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'JNJ     ', price=1324700, match_number=24527),
#  P(stock_locate=13, tracking_number=4, timestamp=b'\x19+\xb3\\dU', order_reference_number=0, buy_sell_indicator=b'B', shares=300, stock=b'AAPL    ', price=2443500, match_number=24530),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x19+\xe9\x86E\xd8', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'BYND    ', price=826900, match_number=24531),
#  P(stock_locate=4456, tracking_number=2, timestamp=b'\x19+\xf8\xdaZ\xcd', order_reference_number=0, buy_sell_indicator=b'B', shares=162, stock=b'JNJ     ', price=1324400, match_number=24532),
#  P(stock_locate=4456, tracking_number=4, timestamp=b'\x19+\xf8\xdaZ\xcd', order_reference_number=0, buy_sell_indicator=b'B', shares=138, stock=b'JNJ     ', price=1324700, match_number=24533),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x19,F\xb8;\xc6', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'BYND    ', price=826900, match_number=24535),
#  P(stock_locate=6020, tracking_number=4, timestamp=b'\x19-\x1d\x0b2k', order_reference_number=0, buy_sell_indicator=b'B', shares=199, stock=b'PCG     ', price=59800, match_number=24541),
#  P(stock_locate=4456, tracking_number=2, timestamp=b'\x19-\xdf~\x7f(', order_reference_number=0, buy_sell_indicator=b'B', shares=200, stock=b'JNJ     ', price=1324700, match_number=24546),
#  P(stock_locate=2734, tracking_number=4, timestamp=b'\x19.\x0btN\x80', order_reference_number=0, buy_sell_indicator=b'B', shares=769, stock=b'FBC     ', price=363500, match_number=24549),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x19.6\xbf \x8c', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'BYND    ', price=826900, match_number=24550),
#  P(stock_locate=4456, tracking_number=2, timestamp=b'\x19.F\x8a\xc0O', order_reference_number=0, buy_sell_indicator=b'B', shares=109, stock=b'JNJ     ', price=1324700, match_number=24552),
#  P(stock_locate=2675, tracking_number=4, timestamp=b'\x19.\xc9/v\xf6', order_reference_number=0, buy_sell_indicator=b'B', shares=600, stock=b'EWZ     ', price=445200, match_number=24557),
#  P(stock_locate=2255, tracking_number=4, timestamp=b'\x190Eb\x7f\xf6', order_reference_number=0, buy_sell_indicator=b'B', shares=50, stock=b'EA      ', price=935000, match_number=24575),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\x190J\x07]\x1f', order_reference_number=0, buy_sell_indicator=b'B', shares=900, stock=b'AAPL    ', price=2444600, match_number=24578),
#  P(stock_locate=6020, tracking_number=4, timestamp=b'\x192\xd6\xd2\xdc\t', order_reference_number=0, buy_sell_indicator=b'B', shares=145, stock=b'PCG     ', price=59800, match_number=24590),
#  P(stock_locate=2675, tracking_number=4, timestamp=b'\x193\x8f\x16\xbe\x96', order_reference_number=0, buy_sell_indicator=b'B', shares=700, stock=b'EWZ     ', price=445900, match_number=24599),
#  P(stock_locate=7629, tracking_number=6, timestamp=b'\x195\xdfm\x9a\x14', order_reference_number=0, buy_sell_indicator=b'B', shares=300, stock=b'T       ', price=381000, match_number=24614),
#  P(stock_locate=13, tracking_number=4, timestamp=b'\x195\xe3\xc2\x07\xcf', order_reference_number=0, buy_sell_indicator=b'B', shares=500, stock=b'AAPL    ', price=2446000, match_number=24616),
#  P(stock_locate=2033, tracking_number=2, timestamp=b'\x196&\x92\x88\x16', order_reference_number=0, buy_sell_indicator=b'B', shares=88, stock=b'DIS     ', price=1295900, match_number=24624),
#  P(stock_locate=13, tracking_number=4, timestamp=b'\x196M\xd1_\x0b', order_reference_number=0, buy_sell_indicator=b'B', shares=150, stock=b'AAPL    ', price=2446000, match_number=24628),
#  P(stock_locate=3268, tracking_number=2, timestamp=b'\x196\x963\xa4\x89', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'GE      ', price=94600, match_number=24632),
#  P(stock_locate=13, tracking_number=4, timestamp=b'\x196\x9d\xf0\xfc\x00', order_reference_number=0, buy_sell_indicator=b'B', shares=25, stock=b'AAPL    ', price=2446000, match_number=24637),
#  P(stock_locate=3502, tracking_number=4, timestamp=b'\x197\xa20\xfeS', order_reference_number=0, buy_sell_indicator=b'B', shares=200, stock=b'GRUB    ', price=320100, match_number=24645),
#  P(stock_locate=3502, tracking_number=4, timestamp=b'\x197\xa2CK@', order_reference_number=0, buy_sell_indicator=b'B', shares=463, stock=b'GRUB    ', price=320100, match_number=24647),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\x198\xe5\xab\x80\xdf', order_reference_number=0, buy_sell_indicator=b'B', shares=200, stock=b'AAPL    ', price=2446000, match_number=24656),
#  P(stock_locate=2734, tracking_number=4, timestamp=b'\x19:\x1d\xd6+S', order_reference_number=0, buy_sell_indicator=b'B', shares=900, stock=b'FBC     ', price=363500, match_number=24664),
#  P(stock_locate=6020, tracking_number=4, timestamp=b'\x19:2C~\xa1', order_reference_number=0, buy_sell_indicator=b'B', shares=2700, stock=b'PCG     ', price=59800, match_number=24668),
#  P(stock_locate=6020, tracking_number=4, timestamp=b'\x19:2p>\xde', order_reference_number=0, buy_sell_indicator=b'B', shares=2716, stock=b'PCG     ', price=59800, match_number=24670),
#  P(stock_locate=6020, tracking_number=4, timestamp=b'\x19;xS\x0e\\', order_reference_number=0, buy_sell_indicator=b'B', shares=1740, stock=b'PCG     ', price=59800, match_number=24677),
#  P(stock_locate=3268, tracking_number=4, timestamp=b'\x19;\xeaah\xed', order_reference_number=0, buy_sell_indicator=b'B', shares=1100, stock=b'GE      ', price=94600, match_number=24680),
#  P(stock_locate=2675, tracking_number=2, timestamp=b'\x19<\xe7\xf0\x7f_', order_reference_number=0, buy_sell_indicator=b'B', shares=1200, stock=b'EWZ     ', price=446000, match_number=24691),
#  P(stock_locate=3268, tracking_number=2, timestamp=b'\x19<\xeb\r\xbc#', order_reference_number=0, buy_sell_indicator=b'B', shares=900, stock=b'GE      ', price=94600, match_number=24693),
#  P(stock_locate=3502, tracking_number=4, timestamp=b'\x19=Q^\xb8\xd1', order_reference_number=0, buy_sell_indicator=b'B', shares=121, stock=b'GRUB    ', price=320100, match_number=24698),
#  P(stock_locate=3502, tracking_number=2, timestamp=b'\x19=\xe1/\x7fU', order_reference_number=0, buy_sell_indicator=b'B', shares=300, stock=b'GRUB    ', price=320100, match_number=24702),
#  P(stock_locate=4978, tracking_number=2, timestamp=b'\x19>"\xb9u}', order_reference_number=0, buy_sell_indicator=b'B', shares=400, stock=b'MCHP    ', price=967400, match_number=24704),
#  ...]

# %% [markdown]
# ## Process Binary Message Data

# %% [markdown]
# The binary file for a single day contains over 350,000,000 messages worth over 12 GB.

# %%
def store_messages(m):
    """Handle occasional storing of all messages"""
    with pd.HDFStore(itch_store) as store:
        for mtype, data in m.items():
            # convert to DataFrame
            data = pd.DataFrame(data)

            # parse timestamp info
            data.timestamp = data.timestamp.apply(int.from_bytes, byteorder='big')
            data.timestamp = pd.to_timedelta(data.timestamp)

            # apply alpha formatting
            if mtype in alpha_formats.keys():
                data = format_alpha(mtype, data)

            s = alpha_length.get(mtype)
            if s:
                s = {c: s.get(c) for c in data.columns}
            dc = ['stock_locate']
            if m == 'R':
                dc.append('stock')
            try:
                print(mtype)
                store.append(mtype,
                         data,
                         format='t',
                         min_itemsize=s,
                         data_columns=dc)
            except Exception as e:
                print(e)
                print(mtype)
                print(data.info())
                print(pd.Series(list(m.keys())).value_counts())
                data.to_csv('data.csv', index=False)
                return 1
    return 0

# %%
messages = defaultdict(list)
message_count = 0
message_type_counter = Counter()

# %% [markdown]
# The script appends the parsed result iteratively to a file in the fast HDF5 format using the `store_messages()` function we just defined to avoid memory constraints (see last section in chapter 2 for more on this format).

# %% [markdown]
# The following code processes the binary file and produces the parsed orders stored by message type:

# %%
start = time() #记录开始时间
with file_name.open('rb') as data: #使用二进制读取模式打开文件，并使用data作为文件句柄
    while True:

        # determine message size in bytes
        message_size = int.from_bytes(data.read(2), byteorder='big', signed=False) #从文件中读取2个字节，解析为一个整数，表示接下来要读取的消息的大小
        
        # get message type by reading first byte
        message_type = data.read(1).decode('ascii') #从文件中读取1个字节，并将其解码为ASCII字符，表示消息的类型        
        message_type_counter.update([message_type]) #使用一个计数器来记录每个消息类型的出现次数

        # read & store message
        try:
            '''
                从文件中读取message_size - 1个字节的数据,
                然后通过特定的格式解析为消息。解析的方式是使用预定义的fstring[message_type]格式,
                这个格式可能是由消息类型决定的。读取的消息会被存储在messages[message_type]列表中.
            '''
            record = data.read(message_size - 1)
            message = message_fields[message_type]._make(unpack(fstring[message_type], record)) 
            #_make() 是 namedtuple 的一个特殊方法，用于从可迭代对象（如元组、列表）创建一个命名元组的实例。此处为对message_fields[message_type]创建实例。
            #struct 模块提供了一种处理 C 语言风格的二进制数据的工具。struct.unpack() 是该模块中的一个函数，用于将打包的二进制数据解包成一个元组。
            #fstring[message_type]指定了数据的类型和顺序，并将record解包为元组，元组由message_fields[message_type]初始化为namedtuple实例
            messages[message_type].append(message) #读取的消息会被存储在messages[message_type]列表中
        except Exception as e: #这是一个捕获异常的语句，表示捕获任何类型的异常，并将异常对象赋给变量 e
            print(e)
            print(message_type)
            print(record)
            print(fstring[message_type])
        
        # deal with system events
        if message_type == 'S':
            seconds = int.from_bytes(message.timestamp, byteorder='big') * 1e-9
            print('\n', event_codes.get(message.event_code.decode('ascii'), 'Error'))
            print(f'\t{format_time(seconds)}\t{message_count:12,.0f}')
            if message.event_code.decode('ascii') == 'C':
                store_messages(messages)
                break
        message_count += 1

        if message_count % 2.5e7 == 0:
            seconds = int.from_bytes(message.timestamp, byteorder='big') * 1e-9
            d = format_time(time() - start)
            print(f'\t{format_time(seconds)}\t{message_count:12,.0f}\t{d}')
            res = store_messages(messages)
            if res == 1:
                print(pd.Series(dict(message_type_counter)).sort_values())
                break
            messages.clear()

print('Duration:', format_time(time() - start))
# Out:
#  Start of Messages
# 	03:02:31.65	  25,000,000
#
#  Start of System Hours
# 	04:00:00.00	  25,241,258
#
#  Start of Market Hours
# 	09:30:00.00	  34,559,279
# 	09:44:09.23	  50,000,000	00:00:34.39
# S
# R
# H
# Y
# L
# Cannot serialize the column [primary_market_maker]
# because its data contents are not [string] but [integer] object dtype
# L
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429498 entries, 0 to 429497
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   stock_locate              429498 non-null  int64
#  1   tracking_number           429498 non-null  int64
#  2   timestamp                 429498 non-null  timedelta64[ns]
#  3   mpid                      429498 non-null  object
#  4   primary_market_maker      429498 non-null  object
#  5   market_maker_mode         429498 non-null  object
#  6   market_participant_state  429498 non-null  object
# dtypes: int64(2), object(4), timedelta64[ns](1)
# memory usage: 22.9+ MB
# None
# S    1
# U    1
# Q    1
# C    1
# I    1
# V    1
# P    1
# E    1
# X    1
# R    1
# F    1
# D    1
# A    1
# L    1
# Y    1
# H    1
# J    1
# Name: count, dtype: int64
# J           2
# V           2
# S           6
# H       17770
# Q       17774
# R       17774
# Y       17852
# C       18352
# P      216824
# L      429498
# E      729902
# F     1673310
# I     2144652
# X     2172786
# U     4265530
# D    18089384
# A    20188582
# dtype: int64
# Duration: 00:00:37.85

# %%
with pd.HDFStore(itch_store) as store:
    mtype = 'Q'
    data = messages[mtype]
    data = pd.DataFrame(data)

    # parse timestamp info
    data.timestamp = data.timestamp.apply(int.from_bytes, byteorder='big')
    data.timestamp = pd.to_timedelta(data.timestamp)

    # apply alpha formatting
    if mtype in alpha_formats.keys():
        data = format_alpha(mtype, data)

    s = alpha_length.get(mtype)
    if s:
        s = {c: s.get(c) for c in data.columns}
    dc = ['stock_locate']
    print(mtype)
    store.append(mtype,
                data,
                format='t',
                min_itemsize=s,
                data_columns=dc)
    store[mtype]
# Out:
# Q
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 19
#      17 dc = ['stock_locate']
#      18 print(mtype)
# ---> 19 store.append(mtype,
#      20             data,
#      21             format='t',
#      22             min_itemsize=s,
#      23             data_columns=dc)
#      24 store[mtype]
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\pytables.py:1317, in HDFStore.append(self, key, value, format, axes, index, append, complib, complevel, columns, min_itemsize, nan_rep, chunksize, expectedrows, dropna, data_columns, encoding, errors)
#    1315     format = get_option("io.hdf.default_format") or "table"
#    1316 format = self._validate_format(format)
# -> 1317 self._write_to_group(
#    1318     key,
#    1319     value,
#    1320     format=format,
#    1321     axes=axes,
#    1322     index=index,
#    1323     append=append,
#    1324     complib=complib,
#    1325     complevel=complevel,
#    1326     min_itemsize=min_itemsize,
#    1327     nan_rep=nan_rep,
#    1328     chunksize=chunksize,
#    1329     expectedrows=expectedrows,
#    1330     dropna=dropna,
#    1331     data_columns=data_columns,
#    1332     encoding=encoding,
#    1333     errors=errors,
#    1334 )
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\pytables.py:1858, in HDFStore._write_to_group(self, key, value, format, axes, index, append, complib, complevel, fletcher32, min_itemsize, chunksize, expectedrows, dropna, nan_rep, data_columns, encoding, errors, track_times)
#    1855     raise ValueError("Compression not supported on Fixed format stores")
#    1857 # write the object
# -> 1858 s.write(
#    1859     obj=value,
#    1860     axes=axes,
#    1861     append=append,
#    1862     complib=complib,
#    1863     complevel=complevel,
#    1864     fletcher32=fletcher32,
#    1865     min_itemsize=min_itemsize,
#    1866     chunksize=chunksize,
#    1867     expectedrows=expectedrows,
#    1868     dropna=dropna,
#    1869     nan_rep=nan_rep,
#    1870     data_columns=data_columns,
#    1871     track_times=track_times,
#    1872 )
#    1874 if isinstance(s, Table) and index:
#    1875     s.create_index(columns=index)
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\pytables.py:4393, in AppendableTable.write(self, obj, axes, append, complib, complevel, fletcher32, min_itemsize, chunksize, expectedrows, dropna, nan_rep, data_columns, track_times)
#    4390     self._handle.remove_node(self.group, "table")
#    4392 # create the axes
# -> 4393 table = self._create_axes(
#    4394     axes=axes,
#    4395     obj=obj,
#    4396     validate=append,
#    4397     min_itemsize=min_itemsize,
#    4398     nan_rep=nan_rep,
#    4399     data_columns=data_columns,
#    4400 )
#    4402 for a in table.axes:
#    4403     a.validate_names()
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\pytables.py:4042, in Table._create_axes(self, axes, obj, validate, nan_rep, data_columns, min_itemsize)
#    4039     existing_col = None
#    4041 new_name = name or f"values_block_{i}"
# -> 4042 data_converted = _maybe_convert_for_string_atom(
#    4043     new_name,
#    4044     blk.values,
#    4045     existing_col=existing_col,
#    4046     min_itemsize=min_itemsize,
#    4047     nan_rep=nan_rep,
#    4048     encoding=self.encoding,
#    4049     errors=self.errors,
#    4050     columns=b_items,
#    4051 )
#    4052 adj_name = _maybe_adjust_name(new_name, self.version)
#    4054 typ = klass._get_atom(data_converted)
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\pytables.py:5090, in _maybe_convert_for_string_atom(name, bvalues, existing_col, min_itemsize, nan_rep, encoding, errors, columns)
#    5088         if inferred_type != "string":
#    5089             error_column_label = columns[i] if len(columns) > i else f"No.{i}"
# -> 5090             raise TypeError(
#    5091                 f"Cannot serialize the column [{error_column_label}]\n"
#    5092                 f"because its data contents are not [string] but "
#    5093                 f"[{inferred_type}] object dtype"
#    5094             )
#    5096 # itemsize is the maximum length of a string (along any dimension)
#    5098 data_converted = _convert_string_array(data, encoding, errors).reshape(data.shape)
#
# TypeError: Cannot serialize the column [cross_type]
# because its data contents are not [string] but [integer] object dtype

# %%
messages['P']
# Out:
# [P(stock_locate=4978, tracking_number=2, timestamp=b'\r\x1d\x8cO)B', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'MCHP    ', price=962700, match_number=17762),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\r H\xafH\xb3', order_reference_number=0, buy_sell_indicator=b'B', shares=20, stock=b'AAPL    ', price=2431200, match_number=17769),
#  P(stock_locate=4978, tracking_number=6, timestamp=b'\r \x98\x12h@', order_reference_number=0, buy_sell_indicator=b'B', shares=218, stock=b'MCHP    ', price=962700, match_number=17772),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\r$\xd1\x9e\xe9\x8d', order_reference_number=0, buy_sell_indicator=b'B', shares=1, stock=b'AAPL    ', price=2431200, match_number=17774),
#  P(stock_locate=8102, tracking_number=2, timestamp=b'\r(\x16\x8b\x92\x03', order_reference_number=0, buy_sell_indicator=b'B', shares=700, stock=b'UGAZ    ', price=156300, match_number=17788),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\r-X\xe5\xcfs', order_reference_number=0, buy_sell_indicator=b'B', shares=21, stock=b'AAPL    ', price=2431700, match_number=17796),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\r6\xedU\x00\xcf', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'AAPL    ', price=2432100, match_number=17807),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\r7\xbc\xd8k2', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'AAPL    ', price=2432100, match_number=17808),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\r995g\xa7', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'TSLA    ', price=3138500, match_number=17811),
#  P(stock_locate=7966, tracking_number=4, timestamp=b'\r995g\xa7', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'TSLA    ', price=3138700, match_number=17812),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\r9\xccR\xeam', order_reference_number=0, buy_sell_indicator=b'B', shares=500, stock=b'AAPL    ', price=2433000, match_number=17816),
#  P(stock_locate=13, tracking_number=4, timestamp=b'\r:\x081+\xbe', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'AAPL    ', price=2433000, match_number=17818),
#  P(stock_locate=7966, tracking_number=4, timestamp=b'\r;\xd4\xb5\n\xe8', order_reference_number=0, buy_sell_indicator=b'B', shares=17, stock=b'TSLA    ', price=3140000, match_number=17824),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\rA\xbf\xdc\xe0\xf6', order_reference_number=0, buy_sell_indicator=b'B', shares=5, stock=b'AAPL    ', price=2433000, match_number=17831),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\rKD\x8b8\xdf', order_reference_number=0, buy_sell_indicator=b'B', shares=131, stock=b'AAPL    ', price=2431200, match_number=17843),
#  P(stock_locate=13, tracking_number=4, timestamp=b'\rKD\x8b8\xdf', order_reference_number=0, buy_sell_indicator=b'B', shares=29, stock=b'AAPL    ', price=2430200, match_number=17844),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\rL\x9a\x0b\x17\x99', order_reference_number=0, buy_sell_indicator=b'B', shares=2, stock=b'AAPL    ', price=2430200, match_number=17845),
#  P(stock_locate=3451, tracking_number=2, timestamp=b'\rN\x88Z^\x1b', order_reference_number=0, buy_sell_indicator=b'B', shares=1, stock=b'GOOGL   ', price=12605200, match_number=17846),
#  P(stock_locate=8386, tracking_number=2, timestamp=b'\rO\n\x80\xed\xc5', order_reference_number=0, buy_sell_indicator=b'B', shares=200, stock=b'VNE     ', price=174000, match_number=17848),
#  P(stock_locate=8386, tracking_number=2, timestamp=b'\rO\n\x82\x12M', order_reference_number=0, buy_sell_indicator=b'B', shares=200, stock=b'VNE     ', price=174000, match_number=17849),
#  P(stock_locate=8386, tracking_number=2, timestamp=b'\rO\n\x8d\xac\xe7', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'VNE     ', price=174000, match_number=17850),
#  P(stock_locate=8386, tracking_number=2, timestamp=b'\rO\x0b\x0e\x06,', order_reference_number=0, buy_sell_indicator=b'B', shares=200, stock=b'VNE     ', price=174900, match_number=17851),
#  P(stock_locate=8386, tracking_number=2, timestamp=b'\rO\x0b\x0f\xb8\x0f', order_reference_number=0, buy_sell_indicator=b'B', shares=200, stock=b'VNE     ', price=174900, match_number=17852),
#  P(stock_locate=8386, tracking_number=2, timestamp=b'\rO\x0b\x18\xbe\xc7', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'VNE     ', price=174900, match_number=17853),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\rR\xddy\xe25', order_reference_number=0, buy_sell_indicator=b'B', shares=10, stock=b'TSLA    ', price=3125300, match_number=17854),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\rTS\x9c\x08\xe6', order_reference_number=0, buy_sell_indicator=b'B', shares=298, stock=b'T       ', price=380000, match_number=17855),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\rUe.g\x1e', order_reference_number=0, buy_sell_indicator=b'B', shares=90, stock=b'TSLA    ', price=3125300, match_number=17856),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\rV\xb7\x9f\x93\xa8', order_reference_number=0, buy_sell_indicator=b'B', shares=144, stock=b'T       ', price=380000, match_number=17862),
#  P(stock_locate=338, tracking_number=2, timestamp=b'\rX\xfeH\xb5\x02', order_reference_number=0, buy_sell_indicator=b'B', shares=5, stock=b'AMD     ', price=324900, match_number=17866),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\r`j\xf9\x8eh', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=17871),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\ra\x99$\xc9R', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=17877),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\rb\x9a\x024F', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'TSLA    ', price=3134600, match_number=17879),
#  P(stock_locate=7428, tracking_number=2, timestamp=b'\rb\xc1)fu', order_reference_number=0, buy_sell_indicator=b'B', shares=30, stock=b'SPY     ', price=3031600, match_number=17880),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\rb\xc7"4\xbd', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=17882),
#  P(stock_locate=338, tracking_number=2, timestamp=b'\rm-\xc9|\t', order_reference_number=0, buy_sell_indicator=b'B', shares=147, stock=b'AMD     ', price=324600, match_number=17896),
#  P(stock_locate=338, tracking_number=4, timestamp=b'\r\x80\x7f#\x19\xc0', order_reference_number=0, buy_sell_indicator=b'B', shares=17, stock=b'AMD     ', price=324000, match_number=17930),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\r\x8a/\x83\xf2\xfb', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'TSLA    ', price=3135200, match_number=17943),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\r\x8b\x8f\x91\xd3H', order_reference_number=0, buy_sell_indicator=b'B', shares=299, stock=b'T       ', price=380000, match_number=17949),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\r\x8b\x93\x8a\xdc\x97', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=17950),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\r\x8d\xd2\x88\xc8]', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'TSLA    ', price=3135200, match_number=17955),
#  P(stock_locate=4478, tracking_number=2, timestamp=b'\r\x8e\xbcT\xf3\x7f', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'JPM     ', price=1261500, match_number=17957),
#  P(stock_locate=338, tracking_number=2, timestamp=b'\r\x92\xe6\x85C"', order_reference_number=0, buy_sell_indicator=b'B', shares=183, stock=b'AMD     ', price=323400, match_number=17960),
#  P(stock_locate=338, tracking_number=4, timestamp=b'\r\x92\xe6\x85C"', order_reference_number=0, buy_sell_indicator=b'B', shares=217, stock=b'AMD     ', price=323300, match_number=17961),
#  P(stock_locate=338, tracking_number=2, timestamp=b'\r\x92\xe6\x85}\xf2', order_reference_number=0, buy_sell_indicator=b'B', shares=32, stock=b'AMD     ', price=323300, match_number=17962),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\r\x9c\xbfB\x97Z', order_reference_number=0, buy_sell_indicator=b'B', shares=300, stock=b'T       ', price=380000, match_number=17971),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\r\x9c\xbfa\x104', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=17972),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\r\x9d\xa9\xf5\x81\xf4', order_reference_number=0, buy_sell_indicator=b'B', shares=50, stock=b'TSLA    ', price=3135600, match_number=17973),
#  P(stock_locate=338, tracking_number=4, timestamp=b'\r\x9d\xb7\xcd\xbb\x80', order_reference_number=0, buy_sell_indicator=b'B', shares=1500, stock=b'AMD     ', price=323000, match_number=17975),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\r\x9f0\xe4rT', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=17979),
#  P(stock_locate=4946, tracking_number=2, timestamp=b'\r\xd0j\xc8\xe8\xf4', order_reference_number=0, buy_sell_indicator=b'B', shares=4, stock=b'MAT     ', price=124200, match_number=18061),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\r\xd8\xaa\xa9\x80\xaa', order_reference_number=0, buy_sell_indicator=b'B', shares=299, stock=b'T       ', price=380000, match_number=18068),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\r\xd9\xe1\x1cm\x10', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=18070),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\r\xdb\x0f\x14\xe6v', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=18072),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\r\xdc=\x0f\x83\x89', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=18073),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\r\xdc\xe4\x87U\xa6', order_reference_number=0, buy_sell_indicator=b'B', shares=299, stock=b'T       ', price=380000, match_number=18075),
#  P(stock_locate=8102, tracking_number=2, timestamp=b'\r\xe9`\xdd\xb0#', order_reference_number=0, buy_sell_indicator=b'B', shares=600, stock=b'UGAZ    ', price=158600, match_number=18083),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\r\xf5\xa4\xe63\xdf', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'BYND    ', price=838500, match_number=18090),
#  P(stock_locate=2754, tracking_number=7, timestamp=b'\x0e\x06\xa6\x9c\xc1\x1e', order_reference_number=0, buy_sell_indicator=b'B', shares=1562, stock=b'FCAU    ', price=141600, match_number=18101),
#  P(stock_locate=8102, tracking_number=2, timestamp=b'\x0e\x12\x85{\xa2\xa7', order_reference_number=0, buy_sell_indicator=b'B', shares=600, stock=b'UGAZ    ', price=158600, match_number=18108),
#  P(stock_locate=8102, tracking_number=2, timestamp=b'\x0e\x12\x85{\xd3\x9e', order_reference_number=0, buy_sell_indicator=b'B', shares=200, stock=b'UGAZ    ', price=158600, match_number=18109),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\x0e\x16X\xefj\xbd', order_reference_number=0, buy_sell_indicator=b'B', shares=300, stock=b'T       ', price=380000, match_number=18111),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\x0e\x16\xf3\xbd\xb5\xc2', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=18113),
#  P(stock_locate=8102, tracking_number=2, timestamp=b'\x0e:A\xab6\x05', order_reference_number=0, buy_sell_indicator=b'B', shares=300, stock=b'UGAZ    ', price=158700, match_number=18153),
#  P(stock_locate=3451, tracking_number=2, timestamp=b'\x0e\\\xd4H\xc5A', order_reference_number=0, buy_sell_indicator=b'B', shares=2, stock=b'GOOGL   ', price=12599500, match_number=18174),
#  P(stock_locate=3451, tracking_number=2, timestamp=b'\x0ev\xb1Q0\x7f', order_reference_number=0, buy_sell_indicator=b'B', shares=3, stock=b'GOOGL   ', price=12599500, match_number=18187),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\x0e\xbeW\xf9U\x8a', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=18222),
#  P(stock_locate=1151, tracking_number=4, timestamp=b'\x0e\xc5\x17\xef\x95\xda', order_reference_number=0, buy_sell_indicator=b'B', shares=15, stock=b'BYND    ', price=837500, match_number=18231),
#  P(stock_locate=1151, tracking_number=4, timestamp=b'\x0e\xea\xa0YW\x04', order_reference_number=0, buy_sell_indicator=b'B', shares=5, stock=b'BYND    ', price=837500, match_number=18265),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x0e\xed\x1c\x96\xe7\x02', order_reference_number=0, buy_sell_indicator=b'B', shares=50, stock=b'BYND    ', price=842500, match_number=18268),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\x0e\xfa*]Ub', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=18276),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\x0e\xfa+)\xa3\x8a', order_reference_number=0, buy_sell_indicator=b'B', shares=197, stock=b'T       ', price=380000, match_number=18277),
#  P(stock_locate=319, tracking_number=2, timestamp=b'\x0f(\x13\xe8\xaaF', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ALV     ', price=790000, match_number=18303),
#  P(stock_locate=868, tracking_number=2, timestamp=b'\x0f3\xbd\xe3\xa0P', order_reference_number=0, buy_sell_indicator=b'B', shares=300, stock=b'BIIB    ', price=3029800, match_number=18309),
#  P(stock_locate=338, tracking_number=2, timestamp=b'\x0fA \xad*H', order_reference_number=0, buy_sell_indicator=b'B', shares=200, stock=b'AMD     ', price=321200, match_number=18316),
#  P(stock_locate=338, tracking_number=4, timestamp=b'\x0fA \xad*H', order_reference_number=0, buy_sell_indicator=b'B', shares=140, stock=b'AMD     ', price=321200, match_number=18317),
#  P(stock_locate=8244, tracking_number=2, timestamp=b'\x0fC\x8fw\xcb\x91', order_reference_number=0, buy_sell_indicator=b'B', shares=50, stock=b'UVXY    ', price=199900, match_number=18318),
#  P(stock_locate=5255, tracking_number=4, timestamp=b'\x0fJ\x0b\xef\x12\xfe', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'MS      ', price=462500, match_number=18324),
#  P(stock_locate=3451, tracking_number=2, timestamp=b'\x0fKX0\x90"', order_reference_number=0, buy_sell_indicator=b'B', shares=13, stock=b'GOOGL   ', price=12599500, match_number=18327),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\x0fNa\xc2\xf2P', order_reference_number=0, buy_sell_indicator=b'B', shares=2, stock=b'TSLA    ', price=3136800, match_number=18329),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x0fe oH\x1c', order_reference_number=0, buy_sell_indicator=b'B', shares=150, stock=b'BYND    ', price=841900, match_number=18347),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\x0fk\x0b\x98\xd7\x9a', order_reference_number=0, buy_sell_indicator=b'B', shares=6, stock=b'TSLA    ', price=3136800, match_number=18356),
#  P(stock_locate=338, tracking_number=2, timestamp=b'\x0fqJ\xbf\x89\xbc', order_reference_number=0, buy_sell_indicator=b'B', shares=43, stock=b'AMD     ', price=321600, match_number=18371),
#  P(stock_locate=1151, tracking_number=6, timestamp=b'\x0f\x87s\xd1\x15\x0f', order_reference_number=0, buy_sell_indicator=b'B', shares=90, stock=b'BYND    ', price=842500, match_number=18400),
#  P(stock_locate=599, tracking_number=2, timestamp=b'\x0f\x8e\xb9\xa2\xc9!', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'AU      ', price=197800, match_number=18407),
#  P(stock_locate=1151, tracking_number=6, timestamp=b'\x0f\xa0\x9b\x03\xe5\xf7', order_reference_number=0, buy_sell_indicator=b'B', shares=90, stock=b'BYND    ', price=842500, match_number=18430),
#  P(stock_locate=1151, tracking_number=4, timestamp=b'\x0f\xa1\xd4I\xae\xdf', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'BYND    ', price=842500, match_number=18436),
#  P(stock_locate=338, tracking_number=4, timestamp=b'\x0f\xa3Z<\x1dU', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'AMD     ', price=320100, match_number=18438),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\x0f\xb1\xdaG%\xae', order_reference_number=0, buy_sell_indicator=b'B', shares=2, stock=b'TSLA    ', price=3136800, match_number=18464),
#  P(stock_locate=1151, tracking_number=4, timestamp=b'\x0f\xc7\xd42M\\', order_reference_number=0, buy_sell_indicator=b'B', shares=80, stock=b'BYND    ', price=842000, match_number=18495),
#  P(stock_locate=338, tracking_number=2, timestamp=b'\x0f\xc9"ZLy', order_reference_number=0, buy_sell_indicator=b'B', shares=50, stock=b'AMD     ', price=318200, match_number=18498),
#  P(stock_locate=338, tracking_number=2, timestamp=b'\x0f\xcd\x98\xc2\x07w', order_reference_number=0, buy_sell_indicator=b'B', shares=500, stock=b'AMD     ', price=318100, match_number=18503),
#  P(stock_locate=338, tracking_number=2, timestamp=b'\x0f\xce\xa7\xb2\x06\r', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'AMD     ', price=318100, match_number=18506),
#  P(stock_locate=338, tracking_number=4, timestamp=b'\x0f\xdd,[F\xee', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'AMD     ', price=318100, match_number=18516),
#  P(stock_locate=338, tracking_number=8, timestamp=b'\x0f\xeb\xedMQR', order_reference_number=0, buy_sell_indicator=b'B', shares=131, stock=b'AMD     ', price=318000, match_number=18549),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\x0f\xf2\xa3\xd0!\xba', order_reference_number=0, buy_sell_indicator=b'B', shares=127, stock=b'AAPL    ', price=2434900, match_number=18557),
#  P(stock_locate=8102, tracking_number=2, timestamp=b'\x10\x12\x9fa\x88_', order_reference_number=0, buy_sell_indicator=b'B', shares=553, stock=b'UGAZ    ', price=157500, match_number=18580),
#  P(stock_locate=338, tracking_number=8, timestamp=b'\x10\x1f\x9a:`\x07', order_reference_number=0, buy_sell_indicator=b'B', shares=70, stock=b'AMD     ', price=320000, match_number=18594),
#  P(stock_locate=338, tracking_number=2, timestamp=b'\x10!f\xba\r^', order_reference_number=0, buy_sell_indicator=b'B', shares=130, stock=b'AMD     ', price=320000, match_number=18595),
#  P(stock_locate=4946, tracking_number=2, timestamp=b'\x10(\xf9\xa4\x82\x8f', order_reference_number=0, buy_sell_indicator=b'B', shares=10, stock=b'MAT     ', price=124600, match_number=18602),
#  P(stock_locate=7966, tracking_number=4, timestamp=b'\x10,\xa4\x92\xd40', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'TSLA    ', price=3137300, match_number=18605),
#  P(stock_locate=7966, tracking_number=6, timestamp=b'\x10,\xa4\x92\xd40', order_reference_number=0, buy_sell_indicator=b'B', shares=82, stock=b'TSLA    ', price=3137200, match_number=18606),
#  P(stock_locate=5688, tracking_number=2, timestamp=b'\x10,\xb7\xe6p\xdb', order_reference_number=0, buy_sell_indicator=b'B', shares=40, stock=b'NVDA    ', price=2036800, match_number=18607),
#  P(stock_locate=338, tracking_number=2, timestamp=b'\x10,\xd4\xe9\x9e\x85', order_reference_number=0, buy_sell_indicator=b'B', shares=53, stock=b'AMD     ', price=321900, match_number=18608),
#  P(stock_locate=13, tracking_number=4, timestamp=b'\x10D\x06K\xc5u', order_reference_number=0, buy_sell_indicator=b'B', shares=28, stock=b'AAPL    ', price=2434900, match_number=18625),
#  P(stock_locate=3451, tracking_number=2, timestamp=b'\x10\\\x95\xea6t', order_reference_number=0, buy_sell_indicator=b'B', shares=2, stock=b'GOOGL   ', price=12597500, match_number=18633),
#  P(stock_locate=319, tracking_number=2, timestamp=b'\x10n\xc2\xcfm\xb1', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ALV     ', price=788000, match_number=18651),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\x10z_\x11\xd3\xf6', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'AAPL    ', price=2434900, match_number=18663),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\x10\x89\x85\xbf\xb7\x9c', order_reference_number=0, buy_sell_indicator=b'B', shares=11, stock=b'AAPL    ', price=2434900, match_number=18674),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\x10\xa6T\xc5$\xd7', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'TSLA    ', price=3141900, match_number=18706),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\x10\xc4M\x8d\xff\xa9', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'TSLA    ', price=3145200, match_number=18735),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\x10\xc7*\xaf7\x18', order_reference_number=0, buy_sell_indicator=b'B', shares=121, stock=b'TSLA    ', price=3148900, match_number=18737),
#  P(stock_locate=7966, tracking_number=4, timestamp=b'\x10\xc7*\xaf7\x18', order_reference_number=0, buy_sell_indicator=b'B', shares=82, stock=b'TSLA    ', price=3149500, match_number=18738),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\x10\xc8\xadU\x90\xb1', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'TSLA    ', price=3150200, match_number=18748),
#  P(stock_locate=855, tracking_number=2, timestamp=b'\x10\xf3\x94\x0f\x9a\xb6', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'BHP     ', price=490400, match_number=18770),
#  P(stock_locate=319, tracking_number=2, timestamp=b'\x10\xfa\x0c\xfel\xc6', order_reference_number=0, buy_sell_indicator=b'B', shares=200, stock=b'ALV     ', price=787000, match_number=18775),
#  P(stock_locate=319, tracking_number=2, timestamp=b'\x10\xfa\x1e\xeaUa', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ALV     ', price=787000, match_number=18776),
#  P(stock_locate=8838, tracking_number=2, timestamp=b'\x115\x1aT\x0b\xaa', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZEAL    ', price=281200, match_number=18815),
#  P(stock_locate=8838, tracking_number=2, timestamp=b'\x115\x1a`\x9a\xf9', order_reference_number=0, buy_sell_indicator=b'B', shares=200, stock=b'ZEAL    ', price=281200, match_number=18817),
#  P(stock_locate=3358, tracking_number=4, timestamp=b'\x11E\xe2\x86L\x05', order_reference_number=0, buy_sell_indicator=b'B', shares=1000, stock=b'GLD     ', price=1404900, match_number=18836),
#  P(stock_locate=3358, tracking_number=2, timestamp=b'\x11E\xe2\x86b\xcf', order_reference_number=0, buy_sell_indicator=b'B', shares=500, stock=b'GLD     ', price=1404900, match_number=18837),
#  P(stock_locate=855, tracking_number=2, timestamp=b'\x11\x84\xab\xe9\xcb\xea', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'BHP     ', price=489900, match_number=18896),
#  P(stock_locate=855, tracking_number=2, timestamp=b'\x11\x85\x1c\xb9\x16O', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'BHP     ', price=489900, match_number=18897),
#  P(stock_locate=5688, tracking_number=2, timestamp=b'\x11\x8b\x9c\x08\t`', order_reference_number=0, buy_sell_indicator=b'B', shares=70, stock=b'NVDA    ', price=2037200, match_number=18905),
#  P(stock_locate=8102, tracking_number=2, timestamp=b'\x11\x91\xca\xe1\xbcu', order_reference_number=0, buy_sell_indicator=b'B', shares=33, stock=b'UGAZ    ', price=158200, match_number=18908),
#  P(stock_locate=5688, tracking_number=2, timestamp=b'\x11\x9b\r\xf4?.', order_reference_number=0, buy_sell_indicator=b'B', shares=2, stock=b'NVDA    ', price=2037200, match_number=18911),
#  P(stock_locate=4456, tracking_number=2, timestamp=b'\x11\xa3F\xdb\x94B', order_reference_number=0, buy_sell_indicator=b'B', shares=200, stock=b'JNJ     ', price=1329700, match_number=18919),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x11\xb7\xfd#\x822', order_reference_number=0, buy_sell_indicator=b'B', shares=10, stock=b'BYND    ', price=845000, match_number=18932),
#  P(stock_locate=1151, tracking_number=8, timestamp=b'\x11\xb7\xfd#\x822', order_reference_number=0, buy_sell_indicator=b'B', shares=4, stock=b'BYND    ', price=842500, match_number=18935),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x11\xb9\xc5`?y', order_reference_number=0, buy_sell_indicator=b'B', shares=6, stock=b'BYND    ', price=842500, match_number=18937),
#  P(stock_locate=13, tracking_number=2, timestamp=b"\x11\xcf\x82\xe4'K", order_reference_number=0, buy_sell_indicator=b'B', shares=20, stock=b'AAPL    ', price=2434900, match_number=18956),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x11\xd4l\x96\xf3\x8f', order_reference_number=0, buy_sell_indicator=b'B', shares=17, stock=b'BYND    ', price=846700, match_number=18961),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\x11\xe8\x8b\xda\x92\xe6', order_reference_number=0, buy_sell_indicator=b'B', shares=27, stock=b'AAPL    ', price=2434900, match_number=18974),
#  P(stock_locate=3451, tracking_number=2, timestamp=b'\x11\xf2\xa9\x1b-\x11', order_reference_number=0, buy_sell_indicator=b'B', shares=30, stock=b'GOOGL   ', price=12597300, match_number=18987),
#  P(stock_locate=3451, tracking_number=4, timestamp=b'\x11\xf2\xa9\x1b-\x11', order_reference_number=0, buy_sell_indicator=b'B', shares=37, stock=b'GOOGL   ', price=12597500, match_number=18988),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\x12\x08H:9_', order_reference_number=0, buy_sell_indicator=b'B', shares=188, stock=b'T       ', price=380000, match_number=19018),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\x12\t\x17\xd7\xc1\xf2', order_reference_number=0, buy_sell_indicator=b'B', shares=220, stock=b'T       ', price=380000, match_number=19019),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\x12\x13\xd4m\xcah', order_reference_number=0, buy_sell_indicator=b'B', shares=2, stock=b'AAPL    ', price=2434900, match_number=19024),
#  P(stock_locate=2733, tracking_number=4, timestamp=b'\x12+\xe0d\xa4\xf6', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'FB      ', price=1895600, match_number=19057),
#  P(stock_locate=6020, tracking_number=2, timestamp=b'\x12\x8fG\xba?\xd6', order_reference_number=0, buy_sell_indicator=b'B', shares=19, stock=b'PCG     ', price=54800, match_number=19153),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x12\xa3{Ig9', order_reference_number=0, buy_sell_indicator=b'B', shares=20, stock=b'BYND    ', price=845500, match_number=19167),
#  P(stock_locate=1151, tracking_number=4, timestamp=b'\x12\xa3{Ig9', order_reference_number=0, buy_sell_indicator=b'B', shares=200, stock=b'BYND    ', price=845400, match_number=19168),
#  P(stock_locate=8744, tracking_number=2, timestamp=b'\x12\xd0\xe7*\xd5*', order_reference_number=0, buy_sell_indicator=b'B', shares=3, stock=b'XNET    ', price=47000, match_number=19184),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\x12\xd1\t\xc5}\x97', order_reference_number=0, buy_sell_indicator=b'B', shares=155, stock=b'T       ', price=380000, match_number=19185),
#  P(stock_locate=855, tracking_number=2, timestamp=b'\x12\xdbQqk\xea', order_reference_number=0, buy_sell_indicator=b'B', shares=90, stock=b'BHP     ', price=487900, match_number=19190),
#  P(stock_locate=855, tracking_number=2, timestamp=b'\x12\xdbQz\xddY', order_reference_number=0, buy_sell_indicator=b'B', shares=90, stock=b'BHP     ', price=487900, match_number=19191),
#  P(stock_locate=8744, tracking_number=2, timestamp=b'\x12\xed\xa59)\xb1', order_reference_number=0, buy_sell_indicator=b'B', shares=13, stock=b'XNET    ', price=47000, match_number=19206),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\x12\xfaB\x15\x9ff', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'AAPL    ', price=2437900, match_number=19225),
#  P(stock_locate=13, tracking_number=4, timestamp=b'\x12\xfef\x171\xe5', order_reference_number=0, buy_sell_indicator=b'B', shares=807, stock=b'AAPL    ', price=2437900, match_number=19236),
#  P(stock_locate=7966, tracking_number=4, timestamp=b'\x13\x0b\x14I\xc3\xea', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'TSLA    ', price=3145600, match_number=19257),
#  P(stock_locate=7966, tracking_number=6, timestamp=b'\x13\x0b\x14I\xc3\xea', order_reference_number=0, buy_sell_indicator=b'B', shares=30, stock=b'TSLA    ', price=3143600, match_number=19258),
#  P(stock_locate=8744, tracking_number=2, timestamp=b'\x13\x0c\xc9j\xbe\x07', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'XNET    ', price=47000, match_number=19259),
#  P(stock_locate=338, tracking_number=2, timestamp=b'\x13\x15\xd0.m1', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'AMD     ', price=321900, match_number=19267),
#  P(stock_locate=338, tracking_number=2, timestamp=b'\x13\x16\xe1-\x18i', order_reference_number=0, buy_sell_indicator=b'B', shares=47, stock=b'AMD     ', price=321900, match_number=19269),
#  P(stock_locate=3758, tracking_number=2, timestamp=b'\x13\x18@|R\xc3', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'HMY     ', price=33200, match_number=19271),
#  P(stock_locate=3758, tracking_number=2, timestamp=b'\x13\x18\xf7=\xe6I', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'HMY     ', price=33200, match_number=19272),
#  P(stock_locate=3758, tracking_number=2, timestamp=b'\x13\x19\xae\x0b3\x8b', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'HMY     ', price=33200, match_number=19274),
#  P(stock_locate=3758, tracking_number=2, timestamp=b'\x13\x1ad\xccE*', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'HMY     ', price=33200, match_number=19275),
#  P(stock_locate=3758, tracking_number=2, timestamp=b'\x13\x1b\x1b\x90\xaa\x9a', order_reference_number=0, buy_sell_indicator=b'B', shares=92, stock=b'HMY     ', price=33200, match_number=19276),
#  P(stock_locate=8744, tracking_number=2, timestamp=b'\x13$\xcee\x02\xf5', order_reference_number=0, buy_sell_indicator=b'B', shares=384, stock=b'XNET    ', price=47000, match_number=19278),
#  P(stock_locate=2033, tracking_number=4, timestamp=b'\x13*j\xf4\x9f\xc0', order_reference_number=0, buy_sell_indicator=b'B', shares=850, stock=b'DIS     ', price=1294000, match_number=19282),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\x138\xf8\xd3\xc2\x02', order_reference_number=0, buy_sell_indicator=b'B', shares=2, stock=b'TSLA    ', price=3150300, match_number=19293),
#  P(stock_locate=7966, tracking_number=4, timestamp=b'\x138\xf8\xd3\xc2\x02', order_reference_number=0, buy_sell_indicator=b'B', shares=2, stock=b'TSLA    ', price=3150300, match_number=19294),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\x13:\xc9\xf7\x0e:', order_reference_number=0, buy_sell_indicator=b'B', shares=30, stock=b'TSLA    ', price=3150200, match_number=19295),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\x13;k\xc5\x9b\xbc', order_reference_number=0, buy_sell_indicator=b'B', shares=4, stock=b'TSLA    ', price=3150200, match_number=19296),
#  P(stock_locate=3451, tracking_number=2, timestamp=b'\x13?\xbd\xa2q:', order_reference_number=0, buy_sell_indicator=b'B', shares=15, stock=b'GOOGL   ', price=12597000, match_number=19298),
#  P(stock_locate=3451, tracking_number=4, timestamp=b'\x13?\xbd\xa2q:', order_reference_number=0, buy_sell_indicator=b'B', shares=115, stock=b'GOOGL   ', price=12597500, match_number=19299),
#  P(stock_locate=7966, tracking_number=2, timestamp=b'\x13A\xc8\xb3\xf1\x10', order_reference_number=0, buy_sell_indicator=b'B', shares=2, stock=b'TSLA    ', price=3150300, match_number=19301),
#  P(stock_locate=7966, tracking_number=4, timestamp=b'\x13A\xc8\xb3\xf1\x10', order_reference_number=0, buy_sell_indicator=b'B', shares=16, stock=b'TSLA    ', price=3150300, match_number=19302),
#  P(stock_locate=3451, tracking_number=2, timestamp=b'\x13QO\xc7\xa3\xd9', order_reference_number=0, buy_sell_indicator=b'B', shares=15, stock=b'GOOGL   ', price=12597500, match_number=19328),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x13\x82\xb0\xb5\xba0', order_reference_number=0, buy_sell_indicator=b'B', shares=10, stock=b'BYND    ', price=840500, match_number=19361),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x13\x82\xb1W\x1a\xc6', order_reference_number=0, buy_sell_indicator=b'B', shares=3, stock=b'BYND    ', price=840500, match_number=19362),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x13\x87\xf6v\xaf\n', order_reference_number=0, buy_sell_indicator=b'B', shares=7, stock=b'BYND    ', price=840500, match_number=19368),
#  P(stock_locate=4619, tracking_number=2, timestamp=b'\x13\xb69\xfa=\xae', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'KO      ', price=535100, match_number=19390),
#  P(stock_locate=3268, tracking_number=4, timestamp=b'\x13\xb8V\x81\x8f\xc1', order_reference_number=0, buy_sell_indicator=b'B', shares=2000, stock=b'GE      ', price=93300, match_number=19399),
#  P(stock_locate=338, tracking_number=6, timestamp=b'\x13\xb9\xce{\xfcb', order_reference_number=0, buy_sell_indicator=b'B', shares=1, stock=b'AMD     ', price=322000, match_number=19408),
#  P(stock_locate=4619, tracking_number=2, timestamp=b'\x13\xbfm\x8f\xa5\xb3', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'KO      ', price=535200, match_number=19418),
#  P(stock_locate=338, tracking_number=6, timestamp=b'\x13\xc1\xfd4\xc3\x0e', order_reference_number=0, buy_sell_indicator=b'B', shares=1431, stock=b'AMD     ', price=323000, match_number=19421),
#  P(stock_locate=8004, tracking_number=4, timestamp=b'\x13\xce\x9d\xe5\xccV', order_reference_number=0, buy_sell_indicator=b'B', shares=900, stock=b'TVIX    ', price=95100, match_number=19443),
#  P(stock_locate=7629, tracking_number=2, timestamp=b"\x13\xde'-9\xed", order_reference_number=0, buy_sell_indicator=b'B', shares=150, stock=b'T       ', price=380000, match_number=19459),
#  P(stock_locate=3268, tracking_number=4, timestamp=b'\x13\xe1\xec\xaa\xd9\xc2', order_reference_number=0, buy_sell_indicator=b'B', shares=463, stock=b'GE      ', price=92500, match_number=19471),
#  P(stock_locate=3268, tracking_number=4, timestamp=b'\x13\xe7e\xf5\x95N', order_reference_number=0, buy_sell_indicator=b'B', shares=37, stock=b'GE      ', price=92500, match_number=19481),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\x13\xfd\xab\xd0\x02\xc7', order_reference_number=0, buy_sell_indicator=b'B', shares=250, stock=b'T       ', price=380000, match_number=19491),
#  P(stock_locate=1671, tracking_number=2, timestamp=b'\x14\x01@\x19\xf4\xa9', order_reference_number=0, buy_sell_indicator=b'B', shares=1, stock=b'CPRX    ', price=52800, match_number=19495),
#  P(stock_locate=3268, tracking_number=2, timestamp=b'\x14\r\x93\xb9o\xbe', order_reference_number=0, buy_sell_indicator=b'B', shares=2, stock=b'GE      ', price=93700, match_number=19511),
#  P(stock_locate=6020, tracking_number=2, timestamp=b'\x14\x0e\xdb\x17\xc2\xf9', order_reference_number=0, buy_sell_indicator=b'B', shares=270, stock=b'PCG     ', price=54800, match_number=19516),
#  P(stock_locate=6020, tracking_number=4, timestamp=b'\x14\x0e\xdb\x17\xc2\xf9', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'PCG     ', price=54900, match_number=19517),
#  P(stock_locate=6020, tracking_number=8, timestamp=b'\x14\x0e\xdb\x17\xc2\xf9', order_reference_number=0, buy_sell_indicator=b'B', shares=530, stock=b'PCG     ', price=55000, match_number=19519),
#  P(stock_locate=1671, tracking_number=2, timestamp=b'\x14\x12h\xa2\xa21', order_reference_number=0, buy_sell_indicator=b'B', shares=5, stock=b'CPRX    ', price=52500, match_number=19522),
#  P(stock_locate=8004, tracking_number=2, timestamp=b'\x14\x1b\xd7\x91#\xa0', order_reference_number=0, buy_sell_indicator=b'B', shares=400, stock=b'TVIX    ', price=94900, match_number=19540),
#  P(stock_locate=338, tracking_number=2, timestamp=b'\x140\xf5\x1ebv', order_reference_number=0, buy_sell_indicator=b'B', shares=1000, stock=b'AMD     ', price=322500, match_number=19576),
#  P(stock_locate=338, tracking_number=2, timestamp=b'\x141\xe7\x02\x9fR', order_reference_number=0, buy_sell_indicator=b'B', shares=1000, stock=b'AMD     ', price=322500, match_number=19578),
#  P(stock_locate=3268, tracking_number=2, timestamp=b'\x143\xc4+V\xd9', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'GE      ', price=94600, match_number=19586),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\x148\xef\xa8\xe0\xea', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=19592),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\x149\x1bS\x1e\xf4', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=19593),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\x149\x1b_\x16\xf6', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=19594),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\x149\x1bj\xdb\xad', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=19595),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\x149\x1f\xae\xca\xd6', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=19596),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\x14:\x98N}\x86', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'T       ', price=380000, match_number=19598),
#  P(stock_locate=1996, tracking_number=4, timestamp=b'\x14:\xab\xbf"m', order_reference_number=0, buy_sell_indicator=b'B', shares=198, stock=b'DGAZ    ', price=1140500, match_number=19600),
#  P(stock_locate=7629, tracking_number=2, timestamp=b'\x14:\xce@;\xea', order_reference_number=0, buy_sell_indicator=b'B', shares=250, stock=b'T       ', price=380000, match_number=19601),
#  P(stock_locate=7906, tracking_number=2, timestamp=b'\x14i\xa19\x04a', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'TQQQ    ', price=683000, match_number=19666),
#  P(stock_locate=8102, tracking_number=4, timestamp=b'\x14qW\xc7@\xae', order_reference_number=0, buy_sell_indicator=b'B', shares=400, stock=b'UGAZ    ', price=161200, match_number=19677),
#  P(stock_locate=8102, tracking_number=4, timestamp=b'\x14\x80\xba\xaco\x1c', order_reference_number=0, buy_sell_indicator=b'B', shares=400, stock=b'UGAZ    ', price=161000, match_number=19688),
#  P(stock_locate=3502, tracking_number=2, timestamp=b'\x14\x80\xf4\xe7\xf5\xcf', order_reference_number=0, buy_sell_indicator=b'B', shares=20, stock=b'GRUB    ', price=331100, match_number=19692),
#  P(stock_locate=8879, tracking_number=6, timestamp=b'\x14\x84\xe4z\xf0\x06', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19793),
#  P(stock_locate=8879, tracking_number=8, timestamp=b'\x14\x84\xe4z\xf0\x06', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19794),
#  P(stock_locate=8879, tracking_number=10, timestamp=b'\x14\x84\xe4z\xf0\x06', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19795),
#  P(stock_locate=8879, tracking_number=12, timestamp=b'\x14\x84\xe4z\xf0\x06', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19796),
#  P(stock_locate=8879, tracking_number=14, timestamp=b'\x14\x84\xe4z\xf0\x06', order_reference_number=0, buy_sell_indicator=b'B', shares=10, stock=b'ZVZZT   ', price=100000, match_number=19797),
#  P(stock_locate=8879, tracking_number=2, timestamp=b'\x14\x84\xe4\x98Em', order_reference_number=0, buy_sell_indicator=b'B', shares=90, stock=b'ZVZZT   ', price=100000, match_number=19798),
#  P(stock_locate=8879, tracking_number=4, timestamp=b'\x14\x84\xe4\x98Em', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19799),
#  P(stock_locate=8879, tracking_number=6, timestamp=b'\x14\x84\xe4\x98Em', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19800),
#  P(stock_locate=8879, tracking_number=8, timestamp=b'\x14\x84\xe4\x98Em', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19801),
#  P(stock_locate=8879, tracking_number=10, timestamp=b'\x14\x84\xe4\x98Em', order_reference_number=0, buy_sell_indicator=b'B', shares=10, stock=b'ZVZZT   ', price=100000, match_number=19802),
#  P(stock_locate=8879, tracking_number=2, timestamp=b'\x14\x84\xe4\xbbe}', order_reference_number=0, buy_sell_indicator=b'B', shares=90, stock=b'ZVZZT   ', price=100000, match_number=19803),
#  P(stock_locate=8879, tracking_number=4, timestamp=b'\x14\x84\xe4\xbbe}', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19804),
#  P(stock_locate=8879, tracking_number=6, timestamp=b'\x14\x84\xe4\xbbe}', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19805),
#  P(stock_locate=8879, tracking_number=8, timestamp=b'\x14\x84\xe4\xbbe}', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19806),
#  P(stock_locate=8879, tracking_number=10, timestamp=b'\x14\x84\xe4\xbbe}', order_reference_number=0, buy_sell_indicator=b'B', shares=10, stock=b'ZVZZT   ', price=100000, match_number=19807),
#  P(stock_locate=8879, tracking_number=2, timestamp=b'\x14\x84\xe4\xc7\xc2\xee', order_reference_number=0, buy_sell_indicator=b'B', shares=90, stock=b'ZVZZT   ', price=100000, match_number=19808),
#  P(stock_locate=8879, tracking_number=4, timestamp=b'\x14\x84\xe4\xc7\xc2\xee', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19809),
#  P(stock_locate=8879, tracking_number=6, timestamp=b'\x14\x84\xe4\xc7\xc2\xee', order_reference_number=0, buy_sell_indicator=b'B', shares=10, stock=b'ZVZZT   ', price=100000, match_number=19810),
#  P(stock_locate=8879, tracking_number=2, timestamp=b'\x14\x84\xe4\xd8\x84\xff', order_reference_number=0, buy_sell_indicator=b'B', shares=90, stock=b'ZVZZT   ', price=100000, match_number=19811),
#  P(stock_locate=8879, tracking_number=4, timestamp=b'\x14\x84\xe4\xd8\x84\xff', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19812),
#  P(stock_locate=8879, tracking_number=6, timestamp=b'\x14\x84\xe4\xd8\x84\xff', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19813),
#  P(stock_locate=8879, tracking_number=8, timestamp=b'\x14\x84\xe4\xd8\x84\xff', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19814),
#  P(stock_locate=8879, tracking_number=10, timestamp=b'\x14\x84\xe4\xd8\x84\xff', order_reference_number=0, buy_sell_indicator=b'B', shares=10, stock=b'ZVZZT   ', price=100000, match_number=19815),
#  P(stock_locate=8879, tracking_number=2, timestamp=b'\x14\x84\xe4\xe97\xe4', order_reference_number=0, buy_sell_indicator=b'B', shares=90, stock=b'ZVZZT   ', price=100000, match_number=19816),
#  P(stock_locate=8879, tracking_number=4, timestamp=b'\x14\x84\xe4\xe97\xe4', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19817),
#  P(stock_locate=8879, tracking_number=6, timestamp=b'\x14\x84\xe4\xe97\xe4', order_reference_number=0, buy_sell_indicator=b'B', shares=10, stock=b'ZVZZT   ', price=100000, match_number=19818),
#  P(stock_locate=8879, tracking_number=2, timestamp=b'\x14\x84\xe4\xfb\x96\xa9', order_reference_number=0, buy_sell_indicator=b'B', shares=90, stock=b'ZVZZT   ', price=100000, match_number=19819),
#  P(stock_locate=8879, tracking_number=4, timestamp=b'\x14\x84\xe4\xfb\x96\xa9', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19820),
#  P(stock_locate=8879, tracking_number=6, timestamp=b'\x14\x84\xe4\xfb\x96\xa9', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19821),
#  P(stock_locate=8879, tracking_number=8, timestamp=b'\x14\x84\xe4\xfb\x96\xa9', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19822),
#  P(stock_locate=8879, tracking_number=10, timestamp=b'\x14\x84\xe4\xfb\x96\xa9', order_reference_number=0, buy_sell_indicator=b'B', shares=10, stock=b'ZVZZT   ', price=100000, match_number=19823),
#  P(stock_locate=8879, tracking_number=2, timestamp=b'\x14\x84\xe4\xfc\t\x81', order_reference_number=0, buy_sell_indicator=b'B', shares=90, stock=b'ZVZZT   ', price=100000, match_number=19824),
#  P(stock_locate=8879, tracking_number=4, timestamp=b'\x14\x84\xe4\xfc\t\x81', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19825),
#  P(stock_locate=8879, tracking_number=6, timestamp=b'\x14\x84\xe4\xfc\t\x81', order_reference_number=0, buy_sell_indicator=b'B', shares=10, stock=b'ZVZZT   ', price=100000, match_number=19826),
#  P(stock_locate=8879, tracking_number=2, timestamp=b'\x14\x84\xe5\x01\xad\r', order_reference_number=0, buy_sell_indicator=b'B', shares=90, stock=b'ZVZZT   ', price=100000, match_number=19827),
#  P(stock_locate=8879, tracking_number=4, timestamp=b'\x14\x84\xe5\x01\xad\r', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19828),
#  P(stock_locate=8879, tracking_number=6, timestamp=b'\x14\x84\xe5\x01\xad\r', order_reference_number=0, buy_sell_indicator=b'B', shares=10, stock=b'ZVZZT   ', price=100000, match_number=19829),
#  P(stock_locate=8879, tracking_number=2, timestamp=b'\x14\x84\xe5 >\x19', order_reference_number=0, buy_sell_indicator=b'B', shares=90, stock=b'ZVZZT   ', price=100000, match_number=19830),
#  P(stock_locate=8879, tracking_number=4, timestamp=b'\x14\x84\xe5 >\x19', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19831),
#  P(stock_locate=8879, tracking_number=6, timestamp=b'\x14\x84\xe5 >\x19', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19832),
#  P(stock_locate=8879, tracking_number=8, timestamp=b'\x14\x84\xe5 >\x19', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19833),
#  P(stock_locate=8879, tracking_number=10, timestamp=b'\x14\x84\xe5 >\x19', order_reference_number=0, buy_sell_indicator=b'B', shares=10, stock=b'ZVZZT   ', price=100000, match_number=19834),
#  P(stock_locate=8879, tracking_number=2, timestamp=b'\x14\x84\xe5"\x83#', order_reference_number=0, buy_sell_indicator=b'B', shares=90, stock=b'ZVZZT   ', price=100000, match_number=19835),
#  P(stock_locate=8879, tracking_number=4, timestamp=b'\x14\x84\xe5"\x83#', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19836),
#  P(stock_locate=8879, tracking_number=6, timestamp=b'\x14\x84\xe5"\x83#', order_reference_number=0, buy_sell_indicator=b'B', shares=10, stock=b'ZVZZT   ', price=100000, match_number=19837),
#  P(stock_locate=8879, tracking_number=2, timestamp=b'\x14\x84\xe5#\x96\xa2', order_reference_number=0, buy_sell_indicator=b'B', shares=90, stock=b'ZVZZT   ', price=100000, match_number=19838),
#  P(stock_locate=8879, tracking_number=4, timestamp=b'\x14\x84\xe5#\x96\xa2', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'ZVZZT   ', price=100000, match_number=19839),
# ...
#  P(stock_locate=13, tracking_number=6, timestamp=b'\x19\t87\xf2.', order_reference_number=0, buy_sell_indicator=b'B', shares=49, stock=b'AAPL    ', price=2440700, match_number=24263),
#  P(stock_locate=1822, tracking_number=4, timestamp=b'\x19\n\r\x85\x11o', order_reference_number=0, buy_sell_indicator=b'B', shares=42, stock=b'CUR     ', price=17700, match_number=24271),
#  P(stock_locate=324, tracking_number=4, timestamp=b'\x19\nF\x1aoH', order_reference_number=0, buy_sell_indicator=b'B', shares=4600, stock=b'AMAG    ', price=100100, match_number=24273),
#  P(stock_locate=324, tracking_number=10, timestamp=b'\x19\nF\x1aoH', order_reference_number=0, buy_sell_indicator=b'B', shares=2600, stock=b'AMAG    ', price=100000, match_number=24276),
#  P(stock_locate=324, tracking_number=4, timestamp=b'\x19\nw\xaf\x84_', order_reference_number=0, buy_sell_indicator=b'B', shares=400, stock=b'AMAG    ', price=100000, match_number=24279),
#  P(stock_locate=2033, tracking_number=2, timestamp=b'\x19\x0c?\x078-', order_reference_number=0, buy_sell_indicator=b'B', shares=1, stock=b'DIS     ', price=1295500, match_number=24284),
#  P(stock_locate=1822, tracking_number=2, timestamp=b'\x19\x0c\xb2\x8f\xdb\xf6', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'CUR     ', price=17700, match_number=24287),
#  P(stock_locate=324, tracking_number=2, timestamp=b'\x19\r\x148\x03?', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'AMAG    ', price=100100, match_number=24290),
#  P(stock_locate=1822, tracking_number=2, timestamp=b'\x19\r\xce\x1br\xa1', order_reference_number=0, buy_sell_indicator=b'B', shares=17, stock=b'CUR     ', price=17700, match_number=24292),
#  P(stock_locate=7612, tracking_number=2, timestamp=b'\x19\x0e\x93\xf1\xcb[', order_reference_number=0, buy_sell_indicator=b'B', shares=2, stock=b'SYK     ', price=2130500, match_number=24297),
#  P(stock_locate=1822, tracking_number=2, timestamp=b'\x19\x0e\x94H\xd48', order_reference_number=0, buy_sell_indicator=b'B', shares=17, stock=b'CUR     ', price=17700, match_number=24298),
#  P(stock_locate=2754, tracking_number=6, timestamp=b'\x19\x0f\xb9XcN', order_reference_number=0, buy_sell_indicator=b'B', shares=456, stock=b'FCAU    ', price=142900, match_number=24302),
#  P(stock_locate=6020, tracking_number=2, timestamp=b'\x19\x0f\xf0\xcc\xff)', order_reference_number=0, buy_sell_indicator=b'B', shares=10, stock=b'PCG     ', price=60400, match_number=24303),
#  P(stock_locate=6020, tracking_number=2, timestamp=b'\x19\x0f\xf0\xcfV\xab', order_reference_number=0, buy_sell_indicator=b'B', shares=190, stock=b'PCG     ', price=60400, match_number=24304),
#  P(stock_locate=2754, tracking_number=6, timestamp=b'\x19\x10{z;\xd6', order_reference_number=0, buy_sell_indicator=b'B', shares=1300, stock=b'FCAU    ', price=142900, match_number=24309),
#  P(stock_locate=1822, tracking_number=2, timestamp=b'\x19\x11\x91\xf9\xa7\x9a', order_reference_number=0, buy_sell_indicator=b'B', shares=24, stock=b'CUR     ', price=17700, match_number=24315),
#  P(stock_locate=1822, tracking_number=4, timestamp=b'\x19\x11\xc2\xd5\xf9T', order_reference_number=0, buy_sell_indicator=b'B', shares=76, stock=b'CUR     ', price=17800, match_number=24321),
#  P(stock_locate=2754, tracking_number=6, timestamp=b'\x19\x12\x1c\x98\x1e\x8e', order_reference_number=0, buy_sell_indicator=b'B', shares=900, stock=b'FCAU    ', price=142900, match_number=24326),
#  P(stock_locate=3450, tracking_number=2, timestamp=b'\x19\x14A5\xab\xd5', order_reference_number=0, buy_sell_indicator=b'B', shares=25, stock=b'GOOG    ', price=12608500, match_number=24339),
#  P(stock_locate=3502, tracking_number=4, timestamp=b'\x19\x16_\x13\t ', order_reference_number=0, buy_sell_indicator=b'B', shares=13, stock=b'GRUB    ', price=318000, match_number=24350),
#  P(stock_locate=3450, tracking_number=2, timestamp=b'\x19\x18\x0ebO\xc6', order_reference_number=0, buy_sell_indicator=b'B', shares=40, stock=b'GOOG    ', price=12601900, match_number=24363),
#  P(stock_locate=1822, tracking_number=2, timestamp=b'\x19\x18\xacvs\x17', order_reference_number=0, buy_sell_indicator=b'B', shares=300, stock=b'CUR     ', price=17700, match_number=24369),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x19\x18\xe64\xea\x10', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'BYND    ', price=826100, match_number=24371),
#  P(stock_locate=2734, tracking_number=2, timestamp=b'\x19\x19-\x1fA\x89', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'FBC     ', price=364000, match_number=24372),
#  P(stock_locate=1822, tracking_number=2, timestamp=b'\x19\x19\xba\xa5\xf3\x8e', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'CUR     ', price=17700, match_number=24377),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x19\x1a(\x8cZ\xf9', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'BYND    ', price=826900, match_number=24378),
#  P(stock_locate=324, tracking_number=2, timestamp=b'\x19\x1a(\xb0Hp', order_reference_number=0, buy_sell_indicator=b'B', shares=199, stock=b'AMAG    ', price=100100, match_number=24379),
#  P(stock_locate=324, tracking_number=2, timestamp=b'\x19\x1a(\xbc\xde\xee', order_reference_number=0, buy_sell_indicator=b'B', shares=39, stock=b'AMAG    ', price=100100, match_number=24380),
#  P(stock_locate=2754, tracking_number=2, timestamp=b'\x19\x1a\xac3\t\xfc', order_reference_number=0, buy_sell_indicator=b'B', shares=200, stock=b'FCAU    ', price=142800, match_number=24387),
#  P(stock_locate=2754, tracking_number=4, timestamp=b'\x19\x1a\xac3j\x8e', order_reference_number=0, buy_sell_indicator=b'B', shares=1100, stock=b'FCAU    ', price=142800, match_number=24389),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x19\x1c\xa7\x81\x15\x9a', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'BYND    ', price=826900, match_number=24421),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x19\x1dYFh\x05', order_reference_number=0, buy_sell_indicator=b'B', shares=60, stock=b'BYND    ', price=826900, match_number=24424),
#  P(stock_locate=2734, tracking_number=2, timestamp=b'\x19\x1d}}\xba\xdd', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'FBC     ', price=364000, match_number=24425),
#  P(stock_locate=3502, tracking_number=4, timestamp=b'\x19\x1d\xc3K\x92\x92', order_reference_number=0, buy_sell_indicator=b'B', shares=400, stock=b'GRUB    ', price=320100, match_number=24427),
#  P(stock_locate=324, tracking_number=2, timestamp=b'\x19\x1e\t\x0bqV', order_reference_number=0, buy_sell_indicator=b'B', shares=63, stock=b'AMAG    ', price=100100, match_number=24428),
#  P(stock_locate=3502, tracking_number=4, timestamp=b'\x19\x1e9\x14\x98\x16', order_reference_number=0, buy_sell_indicator=b'B', shares=395, stock=b'GRUB    ', price=320100, match_number=24432),
#  P(stock_locate=6020, tracking_number=6, timestamp=b'\x19\x1f\x9bT\xaf\xa8', order_reference_number=0, buy_sell_indicator=b'B', shares=999, stock=b'PCG     ', price=60000, match_number=24441),
#  P(stock_locate=6020, tracking_number=2, timestamp=b'\x19\x1f\x9bT\xec\xbd', order_reference_number=0, buy_sell_indicator=b'B', shares=501, stock=b'PCG     ', price=60000, match_number=24442),
#  P(stock_locate=6020, tracking_number=4, timestamp=b'\x19\x1f\x9bT\xec\xbd', order_reference_number=0, buy_sell_indicator=b'B', shares=1100, stock=b'PCG     ', price=60000, match_number=24443),
#  P(stock_locate=1493, tracking_number=4, timestamp=b'\x19"\xcf\xcfq\x84', order_reference_number=0, buy_sell_indicator=b'B', shares=500, stock=b'CLLS    ', price=110200, match_number=24465),
#  P(stock_locate=6399, tracking_number=2, timestamp=b'\x19%\xb8A\xbd\xcc', order_reference_number=0, buy_sell_indicator=b'B', shares=50, stock=b'PSMT    ', price=726000, match_number=24479),
#  P(stock_locate=3256, tracking_number=2, timestamp=b'\x19&~A\x916', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'GDOT    ', price=322000, match_number=24486),
#  P(stock_locate=3256, tracking_number=4, timestamp=b'\x19&~A\x916', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'GDOT    ', price=321700, match_number=24487),
#  P(stock_locate=3256, tracking_number=8, timestamp=b'\x19&~A\x916', order_reference_number=0, buy_sell_indicator=b'B', shares=300, stock=b'GDOT    ', price=321500, match_number=24489),
#  P(stock_locate=3256, tracking_number=2, timestamp=b'\x19&~A\xa3>', order_reference_number=0, buy_sell_indicator=b'B', shares=400, stock=b'GDOT    ', price=321500, match_number=24490),
#  P(stock_locate=6020, tracking_number=2, timestamp=b'\x19&\x99\xddF\xa5', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'PCG     ', price=59700, match_number=24492),
#  P(stock_locate=338, tracking_number=4, timestamp=b'\x19)\x08\x93\x8d\xba', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'AMD     ', price=328900, match_number=24508),
#  P(stock_locate=338, tracking_number=2, timestamp=b'\x19)\x08\x93\xc9\xd6', order_reference_number=0, buy_sell_indicator=b'B', shares=200, stock=b'AMD     ', price=328900, match_number=24509),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x19*\xa4\xf9w\x86', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'BYND    ', price=826900, match_number=24524),
#  P(stock_locate=4456, tracking_number=2, timestamp=b'\x19+-o\xf6h', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'JNJ     ', price=1324700, match_number=24527),
#  P(stock_locate=13, tracking_number=4, timestamp=b'\x19+\xb3\\dU', order_reference_number=0, buy_sell_indicator=b'B', shares=300, stock=b'AAPL    ', price=2443500, match_number=24530),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x19+\xe9\x86E\xd8', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'BYND    ', price=826900, match_number=24531),
#  P(stock_locate=4456, tracking_number=2, timestamp=b'\x19+\xf8\xdaZ\xcd', order_reference_number=0, buy_sell_indicator=b'B', shares=162, stock=b'JNJ     ', price=1324400, match_number=24532),
#  P(stock_locate=4456, tracking_number=4, timestamp=b'\x19+\xf8\xdaZ\xcd', order_reference_number=0, buy_sell_indicator=b'B', shares=138, stock=b'JNJ     ', price=1324700, match_number=24533),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x19,F\xb8;\xc6', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'BYND    ', price=826900, match_number=24535),
#  P(stock_locate=6020, tracking_number=4, timestamp=b'\x19-\x1d\x0b2k', order_reference_number=0, buy_sell_indicator=b'B', shares=199, stock=b'PCG     ', price=59800, match_number=24541),
#  P(stock_locate=4456, tracking_number=2, timestamp=b'\x19-\xdf~\x7f(', order_reference_number=0, buy_sell_indicator=b'B', shares=200, stock=b'JNJ     ', price=1324700, match_number=24546),
#  P(stock_locate=2734, tracking_number=4, timestamp=b'\x19.\x0btN\x80', order_reference_number=0, buy_sell_indicator=b'B', shares=769, stock=b'FBC     ', price=363500, match_number=24549),
#  P(stock_locate=1151, tracking_number=2, timestamp=b'\x19.6\xbf \x8c', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'BYND    ', price=826900, match_number=24550),
#  P(stock_locate=4456, tracking_number=2, timestamp=b'\x19.F\x8a\xc0O', order_reference_number=0, buy_sell_indicator=b'B', shares=109, stock=b'JNJ     ', price=1324700, match_number=24552),
#  P(stock_locate=2675, tracking_number=4, timestamp=b'\x19.\xc9/v\xf6', order_reference_number=0, buy_sell_indicator=b'B', shares=600, stock=b'EWZ     ', price=445200, match_number=24557),
#  P(stock_locate=2255, tracking_number=4, timestamp=b'\x190Eb\x7f\xf6', order_reference_number=0, buy_sell_indicator=b'B', shares=50, stock=b'EA      ', price=935000, match_number=24575),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\x190J\x07]\x1f', order_reference_number=0, buy_sell_indicator=b'B', shares=900, stock=b'AAPL    ', price=2444600, match_number=24578),
#  P(stock_locate=6020, tracking_number=4, timestamp=b'\x192\xd6\xd2\xdc\t', order_reference_number=0, buy_sell_indicator=b'B', shares=145, stock=b'PCG     ', price=59800, match_number=24590),
#  P(stock_locate=2675, tracking_number=4, timestamp=b'\x193\x8f\x16\xbe\x96', order_reference_number=0, buy_sell_indicator=b'B', shares=700, stock=b'EWZ     ', price=445900, match_number=24599),
#  P(stock_locate=7629, tracking_number=6, timestamp=b'\x195\xdfm\x9a\x14', order_reference_number=0, buy_sell_indicator=b'B', shares=300, stock=b'T       ', price=381000, match_number=24614),
#  P(stock_locate=13, tracking_number=4, timestamp=b'\x195\xe3\xc2\x07\xcf', order_reference_number=0, buy_sell_indicator=b'B', shares=500, stock=b'AAPL    ', price=2446000, match_number=24616),
#  P(stock_locate=2033, tracking_number=2, timestamp=b'\x196&\x92\x88\x16', order_reference_number=0, buy_sell_indicator=b'B', shares=88, stock=b'DIS     ', price=1295900, match_number=24624),
#  P(stock_locate=13, tracking_number=4, timestamp=b'\x196M\xd1_\x0b', order_reference_number=0, buy_sell_indicator=b'B', shares=150, stock=b'AAPL    ', price=2446000, match_number=24628),
#  P(stock_locate=3268, tracking_number=2, timestamp=b'\x196\x963\xa4\x89', order_reference_number=0, buy_sell_indicator=b'B', shares=100, stock=b'GE      ', price=94600, match_number=24632),
#  P(stock_locate=13, tracking_number=4, timestamp=b'\x196\x9d\xf0\xfc\x00', order_reference_number=0, buy_sell_indicator=b'B', shares=25, stock=b'AAPL    ', price=2446000, match_number=24637),
#  P(stock_locate=3502, tracking_number=4, timestamp=b'\x197\xa20\xfeS', order_reference_number=0, buy_sell_indicator=b'B', shares=200, stock=b'GRUB    ', price=320100, match_number=24645),
#  P(stock_locate=3502, tracking_number=4, timestamp=b'\x197\xa2CK@', order_reference_number=0, buy_sell_indicator=b'B', shares=463, stock=b'GRUB    ', price=320100, match_number=24647),
#  P(stock_locate=13, tracking_number=2, timestamp=b'\x198\xe5\xab\x80\xdf', order_reference_number=0, buy_sell_indicator=b'B', shares=200, stock=b'AAPL    ', price=2446000, match_number=24656),
#  P(stock_locate=2734, tracking_number=4, timestamp=b'\x19:\x1d\xd6+S', order_reference_number=0, buy_sell_indicator=b'B', shares=900, stock=b'FBC     ', price=363500, match_number=24664),
#  P(stock_locate=6020, tracking_number=4, timestamp=b'\x19:2C~\xa1', order_reference_number=0, buy_sell_indicator=b'B', shares=2700, stock=b'PCG     ', price=59800, match_number=24668),
#  P(stock_locate=6020, tracking_number=4, timestamp=b'\x19:2p>\xde', order_reference_number=0, buy_sell_indicator=b'B', shares=2716, stock=b'PCG     ', price=59800, match_number=24670),
#  P(stock_locate=6020, tracking_number=4, timestamp=b'\x19;xS\x0e\\', order_reference_number=0, buy_sell_indicator=b'B', shares=1740, stock=b'PCG     ', price=59800, match_number=24677),
#  P(stock_locate=3268, tracking_number=4, timestamp=b'\x19;\xeaah\xed', order_reference_number=0, buy_sell_indicator=b'B', shares=1100, stock=b'GE      ', price=94600, match_number=24680),
#  P(stock_locate=2675, tracking_number=2, timestamp=b'\x19<\xe7\xf0\x7f_', order_reference_number=0, buy_sell_indicator=b'B', shares=1200, stock=b'EWZ     ', price=446000, match_number=24691),
#  P(stock_locate=3268, tracking_number=2, timestamp=b'\x19<\xeb\r\xbc#', order_reference_number=0, buy_sell_indicator=b'B', shares=900, stock=b'GE      ', price=94600, match_number=24693),
#  P(stock_locate=3502, tracking_number=4, timestamp=b'\x19=Q^\xb8\xd1', order_reference_number=0, buy_sell_indicator=b'B', shares=121, stock=b'GRUB    ', price=320100, match_number=24698),
#  P(stock_locate=3502, tracking_number=2, timestamp=b'\x19=\xe1/\x7fU', order_reference_number=0, buy_sell_indicator=b'B', shares=300, stock=b'GRUB    ', price=320100, match_number=24702),
#  P(stock_locate=4978, tracking_number=2, timestamp=b'\x19>"\xb9u}', order_reference_number=0, buy_sell_indicator=b'B', shares=400, stock=b'MCHP    ', price=967400, match_number=24704),
#  ...]

# %% [markdown]
# ## Summarize Trading Day

# %% [markdown]
# ### Trading Message Frequency

# %%
counter = pd.Series(message_type_counter).to_frame('# Trades')
counter['Message Type'] = counter.index.map(message_labels.set_index('message_type').name.to_dict())
counter = counter[['Message Type', '# Trades']].sort_values('# Trades', ascending=False)
counter
# Out:
#                                         Message Type  # Trades
# A                      add_order_no_mpid_attribution  10094291
# D                                       order_delete   9044692
# U                                      order_replace   2132765
# X                                       order_cancel   1086393
# I                                               noii   1072326
# F                         add_order_mpid_attribution    836655
# E                                     order_executed    364951
# L                        market_participant_position    214749
# P                                              trade    108412
# C                          order_executed_with_price      9176
# Y  reg_sho_short_sale_price_test_restricted_indic...      8926
# R                                    stock_directory      8887
# Q                                        cross_trade      8887
# H                               stock_trading_action      8885
# S                                       system_event         3
# V          market_wide_circuit_breaker_decline_level         1
# J                                luld_auction_collar         1

# %%
with pd.HDFStore(itch_store) as store:
    store.put('summary', counter)

# %% [markdown]
# ### Top Equities by Traded Value

# %%
with pd.HDFStore(itch_store) as store:
    stocks = store['R'].loc[:, ['stock_locate', 'stock']]
    trades = store['P'].append(store['Q'].rename(columns={'cross_price': 'price'}), sort=False).merge(stocks)

trades['value'] = trades.shares.mul(trades.price)
trades['value_share'] = trades.value.div(trades.value.sum())

trade_summary = trades.groupby('stock').value_share.sum().sort_values(ascending=False)
trade_summary.iloc[:50].plot.bar(figsize=(14, 6), color='darkblue', title='Share of Traded Value')

plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:.0%}'.format(y)))
sns.despine()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 3
#       1 with pd.HDFStore(itch_store) as store:
#       2     stocks = store['R'].loc[:, ['stock_locate', 'stock']]
# ----> 3     trades = store['P'].append(store['Q'].rename(columns={'cross_price': 'price'}), sort=False).merge(stocks)
#       5 trades['value'] = trades.shares.mul(trades.price)
#       6 trades['value_share'] = trades.value.div(trades.value.sum())
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\pytables.py:602, in HDFStore.__getitem__(self, key)
#     601 def __getitem__(self, key: str):
# --> 602     return self.get(key)
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\pytables.py:812, in HDFStore.get(self, key)
#     810 group = self.get_node(key)
#     811 if group is None:
# --> 812     raise KeyError(f"No object named {key} in the file")
#     813 return self._read_group(group)
#
# KeyError: 'No object named P in the file'

# %%
with pd.HDFStore(itch_store) as store:
    print(store.keys())
    print(store['/L'])
# Out:
# ['/H', '/L', '/R', '/S', '/Y', '/summary']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\pytables.py:1806, in HDFStore._create_storer(self, group, format, value, encoding, errors)
#    1805 try:
# -> 1806     cls = _TABLE_MAP[tt]
#    1807 except KeyError as err:
#
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[146], line 3
#       1 with pd.HDFStore(itch_store) as store:
#       2     print(store.keys())
# ----> 3     print(store['/L'])
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\pytables.py:602, in HDFStore.__getitem__(self, key)
#     601 def __getitem__(self, key: str):
# --> 602     return self.get(key)
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\pytables.py:813, in HDFStore.get(self, key)
#     811 if group is None:
#     812     raise KeyError(f"No object named {key} in the file")
# --> 813 return self._read_group(group)
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\pytables.py:1878, in HDFStore._read_group(self, group)
#    1877 def _read_group(self, group: Node):
# -> 1878     s = self._create_storer(group)
#    1879     s.infer_axes()
#    1880     return s.read()
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\pytables.py:1808, in HDFStore._create_storer(self, group, format, value, encoding, errors)
#    1806     cls = _TABLE_MAP[tt]
#    1807 except KeyError as err:
# -> 1808     raise TypeError(
#    1809         f"cannot properly create the storer for: [_TABLE_MAP] [group->"
#    1810         f"{group},value->{type(value)},format->{format}"
#    1811     ) from err
#    1813 return cls(self, group, encoding=encoding, errors=errors)
#
# TypeError: cannot properly create the storer for: [_TABLE_MAP] [group->/L (Group) '',value-><class 'NoneType'>,format->None
